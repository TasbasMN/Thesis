# %%
import os

# %%
def check_download_sample_vcf_files():
    current_path = os.getcwd()
    os.makedirs(os.path.join(current_path, 'sample_vcfs'), exist_ok=True)
    sample_vcf_files_path = os.path.join(current_path, 'sample_vcfs')

    vcf_files = ['PD4248a.vcf', 'PD4199a.vcf', 'PD4198a.vcf', 'PD4194a.vcf', 'PD4192a.vcf', 'PD4120a.vcf',
                'PD4116a.vcf', 'PD4115a.vcf', 'PD4109a.vcf', 'PD4107a.vcf', 'PD4103a.vcf', 'PD4088a.vcf',
                'PD4086a.vcf', 'PD4085a.vcf', 'PD4006a.vcf', 'PD4005a.vcf', 'PD3945a.vcf', 'PD3905a.vcf',
                'PD3904a.vcf', 'PD3890a.vcf', 'PD3851a.vcf']

    if os.path.isabs(sample_vcf_files_path):
        os.chdir(sample_vcf_files_path)

        for vcf_filename in vcf_files:
            vcf_file_path = os.path.join(sample_vcf_files_path, vcf_filename)
            if not os.path.exists(vcf_file_path):
                print('Does not exists: %s' % (vcf_file_path))
            try:
                print('Downloading %s under %s' % (vcf_filename, sample_vcf_files_path))

                # wget -c Continue getting a partially-downloaded file
                # wget -nc  If a file is downloaded more than once in the same directory, the local file will be clobbered, or overwritten
                # cmd="bash -c '" + 'wget -r -l1 -c -nc --no-parent -nd -P ' + chrombased_npy_path + ' ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/lib/nucleosome/chrbased/' + filename + "'"

                # -r When included, the wget will recursively traverse subdirectories in order to obtain all content.
                # -l1 Limit recursion depth to a specific number of levels, by setting the <#> variable to the desired number.
                # -c option to resume a download
                # -nc, --no-clobber If a file is downloaded more than once in the same directory, Wget's behavior depends on a few options, including -nc.  In certain cases, the local file will be clobbered, or overwritten, upon repeated download.  In other cases it will be preserved.
                # -np, --no-parent Do not ever ascend to the parent directory when retrieving recursively.  This is a useful option, since it guarantees that only the files below a certain hierarchy will be downloaded.
                # -nd, --no-directories When included, directories will not be created. All files captured in the wget will be copied directly in to the active directory
                cmd = "bash -c '" + 'wget -r -l1 -c -nc --no-parent -nd ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/' + vcf_filename + "'"
                print("cmd: %s" % cmd)
                os.system(cmd)
            except:
                print("The UCSD ftp site is not responding...")
    else:
        # It has to be an absolute path
        print('%s is not an absolute path.' % (sample_vcf_files_path))

    # go back
    os.chdir(current_path)

# %%
check_download_sample_vcf_files()
# Out:
# Does not exists: /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs/PD4248a.vcf
# Downloading PD4248a.vcf under /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs
# cmd: bash -c 'wget -r -l1 -c -nc --no-parent -nd ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4248a.vcf'
# --2023-07-14 11:57:01--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4248a.vcf
#            => ‘.listing’
# Resolving alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)... 132.249.225.8
# Connecting to alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)|132.249.225.8|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/tools/SigProfilerTopography/sample_vcf_files ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                      1,52M=0,001s
#
# 2023-07-14 11:57:04 (1,52 MB/s) - ‘.listing’ saved [1568]
#
# Removed ‘.listing’.
# --2023-07-14 11:57:04--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4248a.vcf
#            => ‘PD4248a.vcf’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR PD4248a.vcf ... done.
# Length: 59915 (59K)
#
#      0K .......... .......... .......... .......... .......... 85%  120K 0s
#     50K ........                                              100%  165K=0,5s
#
# 2023-07-14 11:57:06 (125 KB/s) - ‘PD4248a.vcf’ saved [59915]
#
# FINISHED --2023-07-14 11:57:06--
# Total wall clock time: 4,3s
# Downloaded: 1 files, 59K in 0,5s (125 KB/s)
# --2023-07-14 11:57:06--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4199a.vcf
#            => ‘.listing’
# Resolving alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)... 132.249.225.8
# Connecting to alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)|132.249.225.8|:21...
# Does not exists: /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs/PD4199a.vcf
# Downloading PD4199a.vcf under /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs
# cmd: bash -c 'wget -r -l1 -c -nc --no-parent -nd ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4199a.vcf'
# connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/tools/SigProfilerTopography/sample_vcf_files ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                      5,33M=0s
#
# 2023-07-14 11:57:08 (5,33 MB/s) - ‘.listing’ saved [1568]
#
# Removed ‘.listing’.
# --2023-07-14 11:57:08--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4199a.vcf
#            => ‘PD4199a.vcf’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR PD4199a.vcf ... done.
# Length: 164069 (160K)
#
#      0K .......... .......... .......... .......... .......... 31% 80,1K 1s
#     50K .......... .......... .......... .......... .......... 62%  399K 0s
#    100K .......... .......... .......... .......... .......... 93%  246K 0s
#    150K ..........                                            100% 82,1K=1,1s
#
# 2023-07-14 11:57:10 (149 KB/s) - ‘PD4199a.vcf’ saved [164069]
#
# FINISHED --2023-07-14 11:57:10--
# Total wall clock time: 4,7s
# Downloaded: 1 files, 160K in 1,1s (149 KB/s)
# --2023-07-14 11:57:10--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4198a.vcf
#            => ‘.listing’
# Resolving alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)... 132.249.225.8
# Connecting to alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)|132.249.225.8|:21...
# Does not exists: /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs/PD4198a.vcf
# Downloading PD4198a.vcf under /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs
# cmd: bash -c 'wget -r -l1 -c -nc --no-parent -nd ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4198a.vcf'
# connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/tools/SigProfilerTopography/sample_vcf_files ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                      2,54M=0,001s
#
# 2023-07-14 11:57:13 (2,54 MB/s) - ‘.listing’ saved [1568]
#
# Removed ‘.listing’.
# --2023-07-14 11:57:13--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4198a.vcf
#            => ‘PD4198a.vcf’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR PD4198a.vcf ... done.
# Length: 107668 (105K)
#
#      0K .......... .......... .......... .......... .......... 47%  101K 1s
#     50K .......... .......... .......... .......... .......... 95%  135K 0s
#    100K .....                                                 100% 8,23K=1,5s
#
# 2023-07-14 11:57:15 (70,6 KB/s) - ‘PD4198a.vcf’ saved [107668]
#
# FINISHED --2023-07-14 11:57:15--
# Total wall clock time: 4,9s
# Downloaded: 1 files, 105K in 1,5s (70,5 KB/s)
# --2023-07-14 11:57:15--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4194a.vcf
#            => ‘.listing’
# Resolving alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)... 132.249.225.8
# Connecting to alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)|132.249.225.8|:21...
# Does not exists: /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs/PD4194a.vcf
# Downloading PD4194a.vcf under /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs
# cmd: bash -c 'wget -r -l1 -c -nc --no-parent -nd ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4194a.vcf'
# connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/tools/SigProfilerTopography/sample_vcf_files ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                      56,0M=0s
#
# 2023-07-14 11:57:18 (56,0 MB/s) - ‘.listing’ saved [1568]
#
# Removed ‘.listing’.
# --2023-07-14 11:57:18--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4194a.vcf
#            => ‘PD4194a.vcf’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR PD4194a.vcf ... done.
# Length: 35093 (34K)
#
#      0K .......... .......... .......... ....                 100%  110K=0,3s
#
# 2023-07-14 11:57:20 (110 KB/s) - ‘PD4194a.vcf’ saved [35093]
#
# FINISHED --2023-07-14 11:57:20--
# Total wall clock time: 4,4s
# Downloaded: 1 files, 34K in 0,3s (110 KB/s)
# --2023-07-14 11:57:20--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4192a.vcf
#            => ‘.listing’
# Resolving alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)...
# Does not exists: /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs/PD4192a.vcf
# Downloading PD4192a.vcf under /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs
# cmd: bash -c 'wget -r -l1 -c -nc --no-parent -nd ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4192a.vcf'
# 132.249.225.8
# Connecting to alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)|132.249.225.8|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/tools/SigProfilerTopography/sample_vcf_files ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                      2,73M=0,001s
#
# 2023-07-14 11:57:28 (2,73 MB/s) - ‘.listing’ saved [1568]
#
# Removed ‘.listing’.
# --2023-07-14 11:57:28--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4192a.vcf
#            => ‘PD4192a.vcf’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR PD4192a.vcf ... done.
# Length: 92642 (90K)
#
#      0K .......... .......... .......... .......... .......... 55%  116K 0s
#     50K .......... .......... .......... ..........           100%  162K=0,7s
#
# 2023-07-14 11:57:30 (133 KB/s) - ‘PD4192a.vcf’ saved [92642]
#
# FINISHED --2023-07-14 11:57:30--
# Total wall clock time: 10s
# Downloaded: 1 files, 90K in 0,7s (133 KB/s)
# Does not exists: /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs/PD4120a.vcf
# Downloading PD4120a.vcf under /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs
# cmd: bash -c 'wget -r -l1 -c -nc --no-parent -nd ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4120a.vcf'
# --2023-07-14 11:57:30--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4120a.vcf
#            => ‘.listing’
# Resolving alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)... 132.249.225.8
# Connecting to alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)|132.249.225.8|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/tools/SigProfilerTopography/sample_vcf_files ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                      8,54M=0s
#
# 2023-07-14 11:57:32 (8,54 MB/s) - ‘.listing’ saved [1568]
#
# Removed ‘.listing’.
# --2023-07-14 11:57:32--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4120a.vcf
#            => ‘PD4120a.vcf’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR PD4120a.vcf ... done.
# Length: 1672536 (1,6M)
#
#      0K .......... .......... .......... .......... ..........  3% 81,4K 19s
#     50K .......... .......... .......... .......... ..........  6%  161K 14s
#    100K .......... .......... .......... .......... ..........  9%  184K 12s
#    150K .......... .......... .......... .......... .......... 12%  201K 10s
#    200K .......... .......... .......... .......... .......... 15%  243K 9s
#    250K .......... .......... .......... .......... .......... 18%  243K 8s
#    300K .......... .......... .......... .......... .......... 21%  244K 8s
#    350K .......... .......... .......... .......... .......... 24%  246K 7s
#    400K .......... .......... .......... .......... .......... 27%  249K 6s
#    450K .......... .......... .......... .......... .......... 30%  249K 6s
#    500K .......... .......... .......... .......... .......... 33%  235K 6s
#    550K .......... .......... .......... .......... .......... 36%  239K 5s
#    600K .......... .......... .......... .......... .......... 39%  249K 5s
#    650K .......... .......... .......... .......... .......... 42%  251K 5s
#    700K .......... .......... .......... .......... .......... 45% 4,33M 4s
#    750K .......... .......... .......... .......... .......... 48%  250K 4s
#    800K .......... .......... .......... .......... .......... 52%  248K 4s
#    850K .......... .......... .......... .......... .......... 55%  252K 3s
#    900K .......... .......... .......... .......... .......... 58% 1,03M 3s
#    950K .......... .......... .......... .......... .......... 61%  307K 3s
#   1000K .......... .......... .......... .......... .......... 64%  252K 3s
#   1050K .......... .......... .......... .......... .......... 67%  273K 2s
#   1100K .......... .......... .......... .......... .......... 70% 1,99M 2s
#   1150K .......... .......... .......... .......... .......... 73%  253K 2s
#   1200K .......... .......... .......... .......... .......... 76% 1,45M 2s
#   1250K .......... .......... .......... .......... .......... 79%  288K 1s
#   1300K .......... .......... .......... .......... .......... 82%  387K 1s
#   1350K .......... .......... .......... .......... .......... 85%  660K 1s
#   1400K .......... .......... .......... .......... .......... 88%  276K 1s
#   1450K .......... .......... .......... .......... .......... 91% 2,14M 0s
#   1500K .......... .......... .......... .......... .......... 94%  548K 0s
#   1550K .......... .......... .......... .......... .......... 97%  443K 0s
#   1600K .......... .......... .......... ...                  100%  524K=5,8s
#
# 2023-07-14 11:57:39 (282 KB/s) - ‘PD4120a.vcf’ saved [1672536]
#
# FINISHED --2023-07-14 11:57:39--
# Total wall clock time: 9,1s
# Downloaded: 1 files, 1,6M in 5,8s (282 KB/s)
# --2023-07-14 11:57:39--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4116a.vcf
#            => ‘.listing’
# Resolving alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)... 132.249.225.8
# Connecting to alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)|132.249.225.8|:21...
# Does not exists: /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs/PD4116a.vcf
# Downloading PD4116a.vcf under /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs
# cmd: bash -c 'wget -r -l1 -c -nc --no-parent -nd ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4116a.vcf'
# connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/tools/SigProfilerTopography/sample_vcf_files ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                      2,13M=0,001s
#
# 2023-07-14 11:57:41 (2,13 MB/s) - ‘.listing’ saved [1568]
#
# Removed ‘.listing’.
# --2023-07-14 11:57:41--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4116a.vcf
#            => ‘PD4116a.vcf’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR PD4116a.vcf ... done.
# Length: 189909 (185K)
#
#      0K .......... .......... .......... .......... .......... 26%  112K 1s
#     50K .......... .......... .......... .......... .......... 53%  248K 1s
#    100K .......... .......... .......... .......... .......... 80% 5,12M 0s
#    150K .......... .......... .......... .....                100%  146K=0,9s
#
# 2023-07-14 11:57:43 (206 KB/s) - ‘PD4116a.vcf’ saved [189909]
#
# FINISHED --2023-07-14 11:57:43--
# Total wall clock time: 4,2s
# Downloaded: 1 files, 185K in 0,9s (206 KB/s)
# Does not exists: /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs/PD4115a.vcf
# Downloading PD4115a.vcf under /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs
# cmd: bash -c 'wget -r -l1 -c -nc --no-parent -nd ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4115a.vcf'
# --2023-07-14 11:57:43--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4115a.vcf
#            => ‘.listing’
# Resolving alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)... 132.249.225.8
# Connecting to alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)|132.249.225.8|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/tools/SigProfilerTopography/sample_vcf_files ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                      3,80M=0s
#
# 2023-07-14 11:57:45 (3,80 MB/s) - ‘.listing’ saved [1568]
#
# Removed ‘.listing’.
# --2023-07-14 11:57:45--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4115a.vcf
#            => ‘PD4115a.vcf’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR PD4115a.vcf ... done.
# Length: 235200 (230K)
#
#      0K .......... .......... .......... .......... .......... 21%  120K 1s
#     50K .......... .......... .......... .......... .......... 43%  247K 1s
#    100K .......... .......... .......... .......... .......... 65% 4,71M 0s
#    150K .......... .......... .......... .......... .......... 87%  262K 0s
#    200K .......... .......... .........                       100%  500K=0,9s
#
# 2023-07-14 11:57:47 (261 KB/s) - ‘PD4115a.vcf’ saved [235200]
#
# FINISHED --2023-07-14 11:57:47--
# Total wall clock time: 4,1s
# Downloaded: 1 files, 230K in 0,9s (261 KB/s)
# --2023-07-14 11:57:47--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4109a.vcf
#            => ‘.listing’
# Resolving alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)... 132.249.225.8
# Connecting to alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)|132.249.225.8|:21...
# Does not exists: /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs/PD4109a.vcf
# Downloading PD4109a.vcf under /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs
# cmd: bash -c 'wget -r -l1 -c -nc --no-parent -nd ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4109a.vcf'
# connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/tools/SigProfilerTopography/sample_vcf_files ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                      2,58M=0,001s
#
# 2023-07-14 11:57:50 (2,58 MB/s) - ‘.listing’ saved [1568]
#
# Removed ‘.listing’.
# --2023-07-14 11:57:50--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4109a.vcf
#            => ‘PD4109a.vcf’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR PD4109a.vcf ... done.
# Length: 233696 (228K)
#
#      0K .......... .......... .......... .......... .......... 21%  117K 2s
#     50K .......... .......... .......... .......... .......... 43%  256K 1s
#    100K .......... .......... .......... .......... .......... 65% 2,65M 0s
#    150K .......... .......... .......... .......... .......... 87%  271K 0s
#    200K .......... .......... ........                        100%  453K=0,9s
#
# 2023-07-14 11:57:51 (257 KB/s) - ‘PD4109a.vcf’ saved [233696]
#
# FINISHED --2023-07-14 11:57:51--
# Total wall clock time: 4,2s
# Downloaded: 1 files, 228K in 0,9s (257 KB/s)
# --2023-07-14 11:57:51--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4107a.vcf
#            => ‘.listing’
# Resolving alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)... 132.249.225.8
# Connecting to alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)|132.249.225.8|:21...
# Does not exists: /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs/PD4107a.vcf
# Downloading PD4107a.vcf under /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs
# cmd: bash -c 'wget -r -l1 -c -nc --no-parent -nd ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4107a.vcf'
# connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/tools/SigProfilerTopography/sample_vcf_files ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                      2,82M=0,001s
#
# 2023-07-14 11:57:54 (2,82 MB/s) - ‘.listing’ saved [1568]
#
# Removed ‘.listing’.
# --2023-07-14 11:57:54--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4107a.vcf
#            => ‘PD4107a.vcf’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR PD4107a.vcf ... done.
# Length: 243377 (238K)
#
#      0K .......... .......... .......... .......... .......... 21%  123K 2s
#     50K .......... .......... .......... .......... .......... 42%  250K 1s
#    100K .......... .......... .......... .......... .......... 63% 4,20M 0s
#    150K .......... .......... .......... .......... .......... 84%  263K 0s
#    200K .......... .......... .......... .......              100%  613K=0,9s
#
# 2023-07-14 11:57:55 (273 KB/s) - ‘PD4107a.vcf’ saved [243377]
#
# FINISHED --2023-07-14 11:57:55--
# Total wall clock time: 4,1s
# Downloaded: 1 files, 238K in 0,9s (273 KB/s)
# --2023-07-14 11:57:55--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4103a.vcf
#            => ‘.listing’
# Resolving alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)... 132.249.225.8
# Connecting to alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)|132.249.225.8|:21...
# Does not exists: /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs/PD4103a.vcf
# Downloading PD4103a.vcf under /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs
# cmd: bash -c 'wget -r -l1 -c -nc --no-parent -nd ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4103a.vcf'
# connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/tools/SigProfilerTopography/sample_vcf_files ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                      1,89M=0,001s
#
# 2023-07-14 11:57:58 (1,89 MB/s) - ‘.listing’ saved [1568]
#
# Removed ‘.listing’.
# --2023-07-14 11:57:58--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4103a.vcf
#            => ‘PD4103a.vcf’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR PD4103a.vcf ... done.
# Length: 126650 (124K)
#
#      0K .......... .......... .......... .......... .......... 40% 99,9K 1s
#     50K .......... .......... .......... .......... .......... 80%  161K 0s
#    100K .......... .......... ...                             100% 78,5K=1,1s
#
# 2023-07-14 11:58:00 (111 KB/s) - ‘PD4103a.vcf’ saved [126650]
#
# FINISHED --2023-07-14 11:58:00--
# Total wall clock time: 4,3s
# Downloaded: 1 files, 124K in 1,1s (111 KB/s)
# --2023-07-14 11:58:00--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4088a.vcf
#            => ‘.listing’
# Resolving alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)... 132.249.225.8
# Connecting to alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)|132.249.225.8|:21...
# Does not exists: /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs/PD4088a.vcf
# Downloading PD4088a.vcf under /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs
# cmd: bash -c 'wget -r -l1 -c -nc --no-parent -nd ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4088a.vcf'
# connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/tools/SigProfilerTopography/sample_vcf_files ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                      67,5M=0s
#
# 2023-07-14 11:58:02 (67,5 MB/s) - ‘.listing’ saved [1568]
#
# Removed ‘.listing’.
# --2023-07-14 11:58:02--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4088a.vcf
#            => ‘PD4088a.vcf’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR PD4088a.vcf ... done.
# Length: 40304 (39K)
#
#      0K .......... .......... .......... .........            100% 65,2K=0,6s
#
# 2023-07-14 11:58:04 (65,2 KB/s) - ‘PD4088a.vcf’ saved [40304]
#
# FINISHED --2023-07-14 11:58:04--
# Total wall clock time: 4,3s
# Downloaded: 1 files, 39K in 0,6s (65,2 KB/s)
# --2023-07-14 11:58:04--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4086a.vcf
#            => ‘.listing’
# Resolving alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)... 132.249.225.8
# Connecting to alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)|132.249.225.8|:21...
# Does not exists: /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs/PD4086a.vcf
# Downloading PD4086a.vcf under /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs
# cmd: bash -c 'wget -r -l1 -c -nc --no-parent -nd ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4086a.vcf'
# connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/tools/SigProfilerTopography/sample_vcf_files ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                      1,03M=0,001s
#
# 2023-07-14 11:58:07 (1,03 MB/s) - ‘.listing’ saved [1568]
#
# Removed ‘.listing’.
# --2023-07-14 11:58:07--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4086a.vcf
#            => ‘PD4086a.vcf’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR PD4086a.vcf ... done.
# Length: 51960 (51K)
#
#      0K .......... .......... .......... .......... .......... 98%  104K 0s
#     50K                                                       100% 1,38T=0,5s
#
# 2023-07-14 11:58:09 (105 KB/s) - ‘PD4086a.vcf’ saved [51960]
#
# FINISHED --2023-07-14 11:58:09--
# Total wall clock time: 4,7s
# Downloaded: 1 files, 51K in 0,5s (105 KB/s)
# --2023-07-14 11:58:09--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4085a.vcf
#            => ‘.listing’
# Resolving alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)... 132.249.225.8
# Connecting to alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)|132.249.225.8|:21...
# Does not exists: /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs/PD4085a.vcf
# Downloading PD4085a.vcf under /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs
# cmd: bash -c 'wget -r -l1 -c -nc --no-parent -nd ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4085a.vcf'
# connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/tools/SigProfilerTopography/sample_vcf_files ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                      1,05M=0,001s
#
# 2023-07-14 11:58:11 (1,05 MB/s) - ‘.listing’ saved [1568]
#
# Removed ‘.listing’.
# --2023-07-14 11:58:11--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4085a.vcf
#            => ‘PD4085a.vcf’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR PD4085a.vcf ... done.
# Length: 63094 (62K)
#
#      0K .......... .......... .......... .......... .......... 81%  104K 0s
#     50K .......... .                                          100%  219K=0,5s
#
# 2023-07-14 11:58:13 (116 KB/s) - ‘PD4085a.vcf’ saved [63094]
#
# FINISHED --2023-07-14 11:58:13--
# Total wall clock time: 3,8s
# Downloaded: 1 files, 62K in 0,5s (115 KB/s)
# --2023-07-14 11:58:13--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4006a.vcf
#            => ‘.listing’
# Resolving alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)... 132.249.225.8
# Connecting to alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)|132.249.225.8|:21...
# Does not exists: /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs/PD4006a.vcf
# Downloading PD4006a.vcf under /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs
# cmd: bash -c 'wget -r -l1 -c -nc --no-parent -nd ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4006a.vcf'
# connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/tools/SigProfilerTopography/sample_vcf_files ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                      2,12M=0,001s
#
# 2023-07-14 11:58:15 (2,12 MB/s) - ‘.listing’ saved [1568]
#
# Removed ‘.listing’.
# --2023-07-14 11:58:15--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4006a.vcf
#            => ‘PD4006a.vcf’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR PD4006a.vcf ... done.
# Length: 217281 (212K)
#
#      0K .......... .......... .......... .......... .......... 23% 84,6K 2s
#     50K .......... .......... .......... .......... .......... 47%  210K 1s
#    100K .......... .......... .......... .......... .......... 70%  166K 0s
#    150K .......... .......... .......... .......... .......... 94%  160K 0s
#    200K .......... ..                                         100% 22,7T=1,4s
#
# 2023-07-14 11:58:18 (147 KB/s) - ‘PD4006a.vcf’ saved [217281]
#
# FINISHED --2023-07-14 11:58:18--
# Total wall clock time: 5,2s
# Downloaded: 1 files, 212K in 1,4s (147 KB/s)
# --2023-07-14 11:58:18--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4005a.vcf
#            => ‘.listing’
# Resolving alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)... 132.249.225.8
# Connecting to alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)|132.249.225.8|:21...
# Does not exists: /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs/PD4005a.vcf
# Downloading PD4005a.vcf under /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs
# cmd: bash -c 'wget -r -l1 -c -nc --no-parent -nd ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4005a.vcf'
# connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/tools/SigProfilerTopography/sample_vcf_files ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                       123M=0s
#
# 2023-07-14 11:58:20 (123 MB/s) - ‘.listing’ saved [1568]
#
# Removed ‘.listing’.
# --2023-07-14 11:58:20--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD4005a.vcf
#            => ‘PD4005a.vcf’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR PD4005a.vcf ... done.
# Length: 144314 (141K)
#
#      0K .......... .......... .......... .......... .......... 35%  118K 1s
#     50K .......... .......... .......... .......... .......... 70%  244K 0s
#    100K .......... .......... .......... ..........           100%  161K=0,9s
#
# 2023-07-14 11:58:22 (159 KB/s) - ‘PD4005a.vcf’ saved [144314]
#
# FINISHED --2023-07-14 11:58:22--
# Total wall clock time: 4,3s
# Downloaded: 1 files, 141K in 0,9s (159 KB/s)
# --2023-07-14 11:58:22--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD3945a.vcf
#            => ‘.listing’
# Resolving alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)... 132.249.225.8
# Connecting to alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)|132.249.225.8|:21...
# Does not exists: /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs/PD3945a.vcf
# Downloading PD3945a.vcf under /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs
# cmd: bash -c 'wget -r -l1 -c -nc --no-parent -nd ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD3945a.vcf'
# connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/tools/SigProfilerTopography/sample_vcf_files ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                      2,46M=0,001s
#
# 2023-07-14 11:58:25 (2,46 MB/s) - ‘.listing’ saved [1568]
#
# Removed ‘.listing’.
# --2023-07-14 11:58:25--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD3945a.vcf
#            => ‘PD3945a.vcf’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR PD3945a.vcf ... done.
# Length: 243267 (238K)
#
#      0K .......... .......... .......... .......... .......... 21%  119K 2s
#     50K .......... .......... .......... .......... .......... 42%  249K 1s
#    100K .......... .......... .......... .......... .......... 63% 3,47M 0s
#    150K .......... .......... .......... .......... .......... 84%  266K 0s
#    200K .......... .......... .......... .......              100%  601K=0,9s
#
# 2023-07-14 11:58:26 (268 KB/s) - ‘PD3945a.vcf’ saved [243267]
#
# FINISHED --2023-07-14 11:58:26--
# Total wall clock time: 4,1s
# Downloaded: 1 files, 238K in 0,9s (268 KB/s)
# --2023-07-14 11:58:26--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD3905a.vcf
#            => ‘.listing’
# Resolving alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)... 132.249.225.8
# Connecting to alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)|132.249.225.8|:21...
# Does not exists: /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs/PD3905a.vcf
# Downloading PD3905a.vcf under /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs
# cmd: bash -c 'wget -r -l1 -c -nc --no-parent -nd ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD3905a.vcf'
# connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/tools/SigProfilerTopography/sample_vcf_files ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                      1,36M=0,001s
#
# 2023-07-14 11:58:29 (1,36 MB/s) - ‘.listing’ saved [1568]
#
# Removed ‘.listing’.
# --2023-07-14 11:58:29--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD3905a.vcf
#            => ‘PD3905a.vcf’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR PD3905a.vcf ... done.
# Length: 108261 (106K)
#
#      0K .......... .......... .......... .......... .......... 47%  118K 0s
#     50K .......... .......... .......... .......... .......... 94%  248K 0s
#    100K .....                                                 100%  107K=0,7s
#
# 2023-07-14 11:58:30 (156 KB/s) - ‘PD3905a.vcf’ saved [108261]
#
# FINISHED --2023-07-14 11:58:30--
# Total wall clock time: 3,9s
# Downloaded: 1 files, 106K in 0,7s (156 KB/s)
# --2023-07-14 11:58:30--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD3904a.vcf
#            => ‘.listing’
# Resolving alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)... 132.249.225.8
# Connecting to alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)|132.249.225.8|:21...
# Does not exists: /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs/PD3904a.vcf
# Downloading PD3904a.vcf under /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs
# cmd: bash -c 'wget -r -l1 -c -nc --no-parent -nd ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD3904a.vcf'
# connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/tools/SigProfilerTopography/sample_vcf_files ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                      1,81M=0,001s
#
# 2023-07-14 11:58:33 (1,81 MB/s) - ‘.listing’ saved [1568]
#
# Removed ‘.listing’.
# --2023-07-14 11:58:33--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD3904a.vcf
#            => ‘PD3904a.vcf’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR PD3904a.vcf ... done.
# Length: 132516 (129K)
#
#      0K .......... .......... .......... .......... .......... 38% 81,3K 1s
#     50K .......... .......... .......... .......... .......... 77%  161K 0s
#    100K .......... .......... .........                       100% 5,31M=0,9s
#
# 2023-07-14 11:58:35 (139 KB/s) - ‘PD3904a.vcf’ saved [132516]
#
# FINISHED --2023-07-14 11:58:35--
# Total wall clock time: 4,4s
# Downloaded: 1 files, 129K in 0,9s (139 KB/s)
# --2023-07-14 11:58:35--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD3890a.vcf
#            => ‘.listing’
# Resolving alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)... 132.249.225.8
# Connecting to alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)|132.249.225.8|:21...
# Does not exists: /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs/PD3890a.vcf
# Downloading PD3890a.vcf under /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs
# cmd: bash -c 'wget -r -l1 -c -nc --no-parent -nd ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD3890a.vcf'
# connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/tools/SigProfilerTopography/sample_vcf_files ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                      2,86M=0,001s
#
# 2023-07-14 11:58:37 (2,86 MB/s) - ‘.listing’ saved [1568]
#
# Removed ‘.listing’.
# --2023-07-14 11:58:37--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD3890a.vcf
#            => ‘PD3890a.vcf’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR PD3890a.vcf ... done.
# Length: 144692 (141K)
#
#      0K .......... .......... .......... .......... .......... 35%  122K 1s
#     50K .......... .......... .......... .......... .......... 70%  237K 0s
#    100K .......... .......... .......... .......... .         100%  449K=0,7s
#
# 2023-07-14 11:58:39 (198 KB/s) - ‘PD3890a.vcf’ saved [144692]
#
# FINISHED --2023-07-14 11:58:39--
# Total wall clock time: 4,1s
# Downloaded: 1 files, 141K in 0,7s (198 KB/s)
# --2023-07-14 11:58:39--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD3851a.vcf
#            => ‘.listing’
# Resolving alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)... 132.249.225.8
# Connecting to alexandrovlab-ftp.ucsd.edu (alexandrovlab-ftp.ucsd.edu)|132.249.225.8|:21...
# Does not exists: /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs/PD3851a.vcf
# Downloading PD3851a.vcf under /run/media/nazif/2F946E411BA61D49/thesis/scripts/sample_vcfs
# cmd: bash -c 'wget -r -l1 -c -nc --no-parent -nd ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD3851a.vcf'
# connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/tools/SigProfilerTopography/sample_vcf_files ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                      1,17M=0,001s
#
# 2023-07-14 11:58:41 (1,17 MB/s) - ‘.listing’ saved [1568]
#
# Removed ‘.listing’.
# --2023-07-14 11:58:41--  ftp://alexandrovlab-ftp.ucsd.edu/pub/tools/SigProfilerTopography/sample_vcf_files/PD3851a.vcf
#            => ‘PD3851a.vcf’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR PD3851a.vcf ... done.
# Length: 42134 (41K)
#
#      0K .......... .......... .......... .......... .         100% 49,8K=0,8s
#
# 2023-07-14 11:58:44 (49,8 KB/s) - ‘PD3851a.vcf’ saved [42134]
#
# FINISHED --2023-07-14 11:58:44--
# Total wall clock time: 5,0s
# Downloaded: 1 files, 41K in 0,8s (49,7 KB/s)
