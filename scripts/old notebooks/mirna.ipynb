# %%
# importing dependencies
from Bio import SeqIO
import pandas as pd
from collections import Counter

# %% [markdown]
# # Importing main sequence
#
# write the relative path of your fasta file below

# %%
# import & parse fasta

with open ("../../data/bcl2_canonical_3utr.fa") as f:
    records = SeqIO.parse(f, "fasta")
    
    transcripts = [str(rec.seq) for rec in records]
    
    # string containing whole sequence
    sequence = "".join(transcripts)

# %% [markdown]
# # Importing miRNA sequence database
#
# download "mature.fa" from [miRBase Database](https://www.mirbase.org/ftp.shtml) and use in the cell below.

# %%
# opening miRNA sequence database


with open("../../data/mature_miRNAs.fa") as fasta_file:
    identifiers = []
    lengths = []
    sequences = []
    cDNA = []

    for seq_record in SeqIO.parse(fasta_file, "fasta"):
        identifiers.append(seq_record.id)
        lengths.append(len(seq_record.seq))
        sequences.append(str(seq_record.seq))

        #back_transcribe() changes U's into T's, complement() takes the complement
        temp = seq_record.seq.back_transcribe()
        temp = temp.complement()
        cDNA.append(str(temp))


# zipping lists into a pandas df
mirna_df = pd.DataFrame(list(zip(identifiers, sequences, cDNA)), columns = ["name", "miRNA_seq", "cDNA_seq"])

# removing non-human entries
mirna_df = mirna_df[mirna_df["name"].str.contains("hsa")]

# fixing index numbers
mirna_df.index = range(1, len(mirna_df)+1)


# deriving MRE sequences and adding as a new column
mirna_df["MRE"] = mirna_df["cDNA_seq"].str[1:9]

# deriving kmer columns
mirna_df["8mer"] = mirna_df["cDNA_seq"].str[:8]
mirna_df["7mer-A1"] = mirna_df["cDNA_seq"].str[:7]
mirna_df["7mer-m8"] = mirna_df["cDNA_seq"].str[1:8]
mirna_df["6mer"] = mirna_df["cDNA_seq"].str[1:7]
mirna_df["offset_6mer"] = mirna_df["cDNA_seq"].str[2:8]


# dropping 8mer and 7mer-A8 values that doesn't start with an A
mirna_df["8mer"].replace({"^[C,T,G]": None}, regex=True, inplace=True)
mirna_df["7mer-A1"].replace({"^[C,T,G]": None}, regex=True, inplace=True)


mirna_df.head()
# Out:
#               name               miRNA_seq                cDNA_seq       MRE  \
# 1    hsa-let-7a-5p  UGAGGUAGUAGGUUGUAUAGUU  ACTCCATCATCCAACATATCAA  CTCCATCA
# 2    hsa-let-7a-3p   CUAUACAAUCUACUGUCUUUC   GATATGTTAGATGACAGAAAG  ATATGTTA
# 3  hsa-let-7a-2-3p  CUGUACAGCCUCCUAGCUUUCC  GACATGTCGGAGGATCGAAAGG  ACATGTCG
# 4    hsa-let-7b-5p  UGAGGUAGUAGGUUGUGUGGUU  ACTCCATCATCCAACACACCAA  CTCCATCA
# 5    hsa-let-7b-3p  CUAUACAACCUACUGCCUUCCC  GATATGTTGGATGACGGAAGGG  ATATGTTG
#
#        8mer  7mer-A1  7mer-m8    6mer offset_6mer
# 1  ACTCCATC  ACTCCAT  CTCCATC  CTCCAT      TCCATC
# 2      None     None  ATATGTT  ATATGT      TATGTT
# 3      None     None  ACATGTC  ACATGT      CATGTC
# 4  ACTCCATC  ACTCCAT  CTCCATC  CTCCAT      TCCATC
# 5      None     None  ATATGTT  ATATGT      TATGTT

# %% [markdown]
# # Exploratory Data Analysis

# %%
#checking miRNAs for duplicates

print(f"Total number of miRNA sequences: {len(mirna_df)}")
print("Duplicated MRE sequences: ", mirna_df["MRE"].duplicated().sum())
print("Duplicated miRNA sequences: ", mirna_df["miRNA_seq"].duplicated().sum())
print("Duplicated IDs: ", mirna_df["name"].duplicated().sum())
mirna_df.head()
# Out:
# Total number of miRNA sequences: 2656
# Duplicated MRE sequences:  298
# Duplicated miRNA sequences:  24
# Duplicated IDs:  0
#               name               miRNA_seq                cDNA_seq       MRE  \
# 1    hsa-let-7a-5p  UGAGGUAGUAGGUUGUAUAGUU  ACTCCATCATCCAACATATCAA  CTCCATCA
# 2    hsa-let-7a-3p   CUAUACAAUCUACUGUCUUUC   GATATGTTAGATGACAGAAAG  ATATGTTA
# 3  hsa-let-7a-2-3p  CUGUACAGCCUCCUAGCUUUCC  GACATGTCGGAGGATCGAAAGG  ACATGTCG
# 4    hsa-let-7b-5p  UGAGGUAGUAGGUUGUGUGGUU  ACTCCATCATCCAACACACCAA  CTCCATCA
# 5    hsa-let-7b-3p  CUAUACAACCUACUGCCUUCCC  GATATGTTGGATGACGGAAGGG  ATATGTTG
#
#        8mer  7mer-A1  7mer-m8    6mer offset_6mer
# 1  ACTCCATC  ACTCCAT  CTCCATC  CTCCAT      TCCATC
# 2      None     None  ATATGTT  ATATGT      TATGTT
# 3      None     None  ACATGTC  ACATGT      CATGTC
# 4  ACTCCATC  ACTCCAT  CTCCATC  CTCCAT      TCCATC
# 5      None     None  ATATGTT  ATATGT      TATGTT

# %%
# exploring the imported sequence

print(f"The length of target sequence: {len(sequence)}")
print(f"Total number of transcripts in the file: {len(transcripts)}")
print(f"Total number of A: {sequence.count('A')}")
print(f"Total number of T: {sequence.count('T')}")
print(f"Total number of C: {sequence.count('C')}")
print(f"Total number of G: {sequence.count('G')}")
print(f"GC ratio:  {(sequence.count('G') + sequence.count('C')) / len(sequence)}" )
# Out:
# The length of target sequence: 5279
# Total number of transcripts in the file: 1
# Total number of A: 1550
# Total number of T: 1588
# Total number of C: 1001
# Total number of G: 1140
# GC ratio:  0.4055692365978405

# %% [markdown]
# # required functions

# %%
# generator function to find kmers of k size:

def generate_kmers(sequence, k=6):
    for nucleotide in range(len(sequence) - k + 1):
        yield sequence[nucleotide: nucleotide + k]

# %%
# function to find seed sequences in kmers
def find_seed_in_kmers(kmer_generator, seeds):
    
    # copying seeds dict into the function
    temp = seeds.copy()
    
    # counter that iterates through kmers to find matches
    counter = Counter([kmer for kmer in kmer_generator if kmer in temp])

    # returns dict, sorted by the number of matches            
    return dict(sorted(counter.items(), key = lambda item: item[1], reverse=True))

# %%
# creating a dict that holds all possible kmers to iterate on

columns_to_merge = ["8mer", "7mer-A1", "7mer-m8", "6mer"]
temp = []
for column in columns_to_merge:
    temp.extend(mirna_df[column].tolist())

# final dict containing all possible kmers and their corresponding hit values (currently 0)
seed_kmers = {k: 0 for k in temp}

# %% [markdown]
# # Results
#
# the cell below computes and prints 8mer matches

# %%
# generate_kmers will find kmers in the imported fasta
# find_seed_in_kmers will find matches and counts them 
seeds = find_seed_in_kmers(generate_kmers(sequence, k=8), seed_kmers)


# for loop that prints only the seeds with at least one hit
for kmer, count in seeds.items():
    if count != 0:
        # fetches miRNA names having that specific seed sequence
        matching_mirnas = mirna_df.loc[(mirna_df["8mer"] == kmer)]["name"].values
        print(f"Seed: {kmer},    {count} matches,    matching miRNA(s): {matching_mirnas}")
# Out:
# Seed: ACACACAC,    5 matches,    matching miRNA(s): ['hsa-miR-6867-5p']
# Seed: ATGCATCT,    2 matches,    matching miRNA(s): ['hsa-miR-1277-3p']
# Seed: ACATTGTC,    2 matches,    matching miRNA(s): ['hsa-miR-194-5p']
# Seed: ATTGTCAG,    1 matches,    matching miRNA(s): ['hsa-miR-212-3p' 'hsa-miR-132-3p']
# Seed: ACATCACA,    1 matches,    matching miRNA(s): ['hsa-miR-142-3p']
# Seed: AACGTCGA,    1 matches,    matching miRNA(s): ['hsa-miR-1301-3p' 'hsa-miR-5047']
# Seed: AAAGGGAA,    1 matches,    matching miRNA(s): ['hsa-miR-4755-5p' 'hsa-miR-5006-3p']
# Seed: AAGGGAAA,    1 matches,    matching miRNA(s): ['hsa-miR-204-5p' 'hsa-miR-211-5p']
# Seed: ACTCCTGT,    1 matches,    matching miRNA(s): ['hsa-miR-5004-5p']
# Seed: ACCATCTG,    1 matches,    matching miRNA(s): ['hsa-miR-379-5p']
# Seed: AGGGTTCC,    1 matches,    matching miRNA(s): ['hsa-miR-6814-5p']
# Seed: AGAAGAGA,    1 matches,    matching miRNA(s): ['hsa-miR-942-5p']
# Seed: AGAGACTC,    1 matches,    matching miRNA(s): ['hsa-miR-3921' 'hsa-miR-4653-5p']
# Seed: AAGAAACA,    1 matches,    matching miRNA(s): ['hsa-miR-6844']
# Seed: AACCTGCC,    1 matches,    matching miRNA(s): ['hsa-miR-4804-5p']
# Seed: ACCTGCCT,    1 matches,    matching miRNA(s): ['hsa-miR-184']
# Seed: AGAGGGAA,    1 matches,    matching miRNA(s): ['hsa-miR-4287' 'hsa-miR-4685-3p']
# Seed: AGGACATG,    1 matches,    matching miRNA(s): ['hsa-miR-486-5p']
# Seed: AACGTGAG,    1 matches,    matching miRNA(s): ['hsa-miR-7703']
# Seed: AAATCCTA,    1 matches,    matching miRNA(s): ['hsa-miR-651-5p']
# Seed: ATTTATCT,    1 matches,    matching miRNA(s): ['hsa-miR-3121-3p']
# Seed: ATTGTATT,    1 matches,    matching miRNA(s): ['hsa-miR-4803']
# Seed: ATCGTTTT,    1 matches,    matching miRNA(s): ['hsa-miR-548p']
# Seed: AGGTGAGA,    1 matches,    matching miRNA(s): ['hsa-miR-6777-3p']
# Seed: ATTGTGAC,    1 matches,    matching miRNA(s): ['hsa-miR-141-3p' 'hsa-miR-200a-3p']
# Seed: AGACCCAC,    1 matches,    matching miRNA(s): ['hsa-miR-6776-5p']
# Seed: AAACCTGT,    1 matches,    matching miRNA(s): ['hsa-miR-4520-2-3p']
# Seed: AGGGAACA,    1 matches,    matching miRNA(s): ['hsa-miR-6780b-3p']
# Seed: ACAGAATG,    1 matches,    matching miRNA(s): ['hsa-miR-550a-3p']
# Seed: AATATTAT,    1 matches,    matching miRNA(s): ['hsa-miR-374a-5p']
# Seed: ATCCTGTG,    1 matches,    matching miRNA(s): ['hsa-miR-1197']
# Seed: ACGTGGTA,    1 matches,    matching miRNA(s): ['hsa-miR-767-5p']
# Seed: ACGGGATT,    1 matches,    matching miRNA(s): ['hsa-miR-18b-3p']
# Seed: ATATATAT,    1 matches,    matching miRNA(s): ['hsa-miR-5011-5p']
# Seed: AGGTCACG,    1 matches,    matching miRNA(s): ['hsa-miR-1825']
# Seed: AATAACAG,    1 matches,    matching miRNA(s): ['hsa-miR-5701']
# Seed: AGTCATTT,    1 matches,    matching miRNA(s): ['hsa-miR-545-5p']
# Seed: AACAGAGA,    1 matches,    matching miRNA(s): ['hsa-miR-6818-3p']
# Seed: ACTCCTCT,    1 matches,    matching miRNA(s): ['hsa-miR-3150b-3p' 'hsa-miR-4784']
# Seed: AAAGGAGA,    1 matches,    matching miRNA(s): ['hsa-miR-3059-5p']
# Seed: AGGAGAAG,    1 matches,    matching miRNA(s): ['hsa-miR-877-3p']
# Seed: AGAACCTC,    1 matches,    matching miRNA(s): ['hsa-miR-432-5p']
# Seed: ACCTCCTC,    1 matches,    matching miRNA(s): ['hsa-miR-765']
# Seed: AGTCCCTC,    1 matches,    matching miRNA(s): ['hsa-miR-4270']
# Seed: AGTCACAG,    1 matches,    matching miRNA(s): ['hsa-miR-6733-3p']
# Seed: ACCTCAAT,    1 matches,    matching miRNA(s): ['hsa-miR-4653-3p']
# Seed: ACCTCTCT,    1 matches,    matching miRNA(s): ['hsa-miR-185-5p' 'hsa-miR-4306' 'hsa-miR-4644']
# Seed: ATTAGGAA,    1 matches,    matching miRNA(s): ['hsa-miR-500a-5p']
# Seed: ACACATGT,    1 matches,    matching miRNA(s): ['hsa-miR-3177-5p']
# Seed: AATAGTCT,    1 matches,    matching miRNA(s): ['hsa-miR-361-5p']
# Seed: AGACTTTC,    1 matches,    matching miRNA(s): ['hsa-miR-4766-5p']
# Seed: AGATCTTT,    1 matches,    matching miRNA(s): ['hsa-miR-6508-5p']
# Seed: ATGGGACA,    1 matches,    matching miRNA(s): ['hsa-miR-10a-5p' 'hsa-miR-10b-5p']
# Seed: AAAGGACA,    1 matches,    matching miRNA(s): ['hsa-miR-7152-5p']
# Seed: ACATTTGT,    1 matches,    matching miRNA(s): ['hsa-miR-30a-5p' 'hsa-miR-30c-5p' 'hsa-miR-30d-5p' 'hsa-miR-30b-5p'
#  'hsa-miR-30e-5p']
# Seed: AGGGAGGA,    1 matches,    matching miRNA(s): ['hsa-miR-4667-3p']
# Seed: ATCAGGGA,    1 matches,    matching miRNA(s): ['hsa-miR-2114-5p']
# Seed: ATTTTGAA,    1 matches,    matching miRNA(s): ['hsa-miR-5582-3p']
# Seed: AGCATGGC,    1 matches,    matching miRNA(s): ['hsa-miR-126-3p']
# Seed: ACTAACAG,    1 matches,    matching miRNA(s): ['hsa-miR-219a-5p' 'hsa-miR-4782-3p' 'hsa-miR-6766-3p']
# Seed: ACCTTCTG,    1 matches,    matching miRNA(s): ['hsa-miR-7-5p']
# Seed: ATGAATGG,    1 matches,    matching miRNA(s): ['hsa-miR-9898']
# Seed: AGCACAGA,    1 matches,    matching miRNA(s): ['hsa-miR-187-3p']
# Seed: ACAGAAGA,    1 matches,    matching miRNA(s): ['hsa-miR-6740-3p']
# Seed: ATCAAGAA,    1 matches,    matching miRNA(s): ['hsa-miR-5584-3p']
# Seed: AATTCTGA,    1 matches,    matching miRNA(s): ['hsa-miR-499a-5p']
# Seed: AGACTGTA,    1 matches,    matching miRNA(s): ['hsa-miR-6719-3p']
# Seed: ATTTCATT,    1 matches,    matching miRNA(s): ['hsa-miR-559']
# Seed: AGAGTGAC,    1 matches,    matching miRNA(s): ['hsa-miR-1304-3p']
# Seed: AAGGATAC,    1 matches,    matching miRNA(s): ['hsa-miR-202-5p']
# Seed: AACTTTCC,    1 matches,    matching miRNA(s): ['hsa-miR-488-3p']

# %% [markdown]
# the cell below computes 7mer matches

# %%
# top matching 7mers

seeds = find_seed_in_kmers(generate_kmers(sequence, 7), seed_kmers)

for kmer, count in seeds.items():
    if count != 0:
        possible_sequences = mirna_df.loc[(mirna_df['7mer-A1'] == kmer) | (mirna_df['7mer-m8'] == kmer)]["name"].values
        print(f"{kmer}: {count} - {possible_sequences}")
# Out:
# ACACACA: 8 - ['hsa-miR-6867-5p']
# CACACAC: 6 - ['hsa-miR-6867-5p']
# ACAGAAT: 5 - ['hsa-miR-550a-3p']
# TGTTGTT: 4 - ['hsa-miR-3529-3p']
# GAAGTGA: 4 - ['hsa-miR-6837-3p']
# GGGCCCT: 4 - ['hsa-miR-1247-3p']
# CATTGTC: 3 - ['hsa-miR-194-5p']
# ATTGTCA: 3 - ['hsa-miR-212-3p' 'hsa-miR-132-3p']
# GGGGAAG: 3 - ['hsa-miR-3127-3p' 'hsa-miR-6756-3p']
# AACAGAG: 3 - ['hsa-miR-6818-3p']
# AGAGGGA: 3 - ['hsa-miR-4287' 'hsa-miR-4685-3p' 'hsa-miR-6867-3p']
# AAGGACA: 3 - ['hsa-miR-7152-5p']
# AGAACCT: 3 - ['hsa-miR-432-5p']
# CCCTCCA: 3 - ['hsa-miR-6799-5p']
# ACTGTAG: 3 - ['hsa-miR-489-3p']
# AAAGAAG: 3 - ['hsa-miR-4659a-3p' 'hsa-miR-4659b-3p']
# AAACCTG: 3 - ['hsa-miR-4520-2-3p' 'hsa-miR-7850-5p']
# TGCATCT: 3 - ['hsa-miR-1277-3p']
# TTGTATT: 3 - ['hsa-miR-4803']
# ATTCTGA: 3 - ['hsa-miR-499a-5p']
# GACCTTT: 3 - ['hsa-miR-875-3p']
# TCAGGGA: 3 - ['hsa-miR-2114-5p']
# CTTTTGT: 3 - ['hsa-miR-570-3p']
# AGTAAAT: 3 - ['hsa-miR-4729' 'hsa-miR-5696']
# ATGAATG: 3 - ['hsa-miR-9898']
# GATCTTT: 3 - ['hsa-miR-6508-5p' 'hsa-miR-8067']
# TTTATTA: 3 - ['hsa-miR-5692a']
# ATCAAGA: 3 - ['hsa-miR-5584-3p']
# TTTTAAA: 3 - ['hsa-miR-4282']
# CCCCAAA: 2 - ['hsa-miR-193b-5p']
# CAAACAA: 2 - ['hsa-miR-8068']
# AGTGATG: 2 - ['hsa-miR-4999-3p']
# AATAACA: 2 - ['hsa-miR-5701']
# ACATTAT: 2 - ['hsa-miR-2054']
# TAAGACA: 2 - ['hsa-miR-4778-5p']
# CTCCACC: 2 - ['hsa-miR-6134']
# CCACCTG: 2 - ['hsa-miR-8071']
# ACCTGGA: 2 - ['hsa-miR-4535' 'hsa-miR-6861-3p']
# CTTTCCA: 2 - ['hsa-miR-6730-5p']
# CTGAAGA: 2 - ['hsa-miR-6505-3p']
# AAAGGAC: 2 - ['hsa-miR-7152-5p']
# AAGGACC: 2 - ['hsa-miR-6783-3p']
# GGACCTG: 2 - ['hsa-miR-3690']
# GGAGAAG: 2 - ['hsa-miR-877-3p']
# GAGAAGG: 2 - ['hsa-miR-1236-3p']
# GTGTTCA: 2 - ['hsa-miR-125b-2-3p']
# ATTTCTT: 2 - ['hsa-miR-3133']
# GAGGGAG: 2 - ['hsa-miR-4469']
# AGGGAGG: 2 - ['hsa-miR-4667-3p']
# TCCTGTG: 2 - ['hsa-miR-1197']
# ACCTGGT: 2 - ['hsa-miR-4776-5p']
# GTGGGAG: 2 - ['hsa-miR-6865-3p']
# GGGAGGA: 2 - ['hsa-miR-4667-3p']
# GGGAACT: 2 - ['hsa-miR-4780']
# GAGATTT: 2 - ['hsa-miR-520f-5p']
# ATTTCCA: 2 - ['hsa-miR-12135']
# TTCCACG: 2 - ['hsa-miR-18a-5p' 'hsa-miR-18b-5p' 'hsa-miR-4735-3p']
# GGGAAAA: 2 - ['hsa-miR-6832-3p']
# TAGGAAA: 2 - ['hsa-miR-501-5p']
# TTTAAGC: 2 - ['hsa-miR-10a-3p']
# GAGAAAA: 2 - ['hsa-miR-130a-5p']
# ATTTTGG: 2 - ['hsa-miR-548as-3p']
# TGGCTCT: 2 - ['hsa-miR-4523']
# AGAAACA: 2 - ['hsa-miR-6844']
# AGGAAGT: 2 - ['hsa-miR-205-5p']
# GTGAACA: 2 - ['hsa-miR-6500-3p']
# TTACCCA: 2 - ['hsa-miR-4506']
# ACCCAGA: 2 - ['hsa-miR-193a-5p']
# GGGGCCC: 2 - ['hsa-miR-5587-3p']
# CTCACTG: 2 - ['hsa-miR-1236-5p']
# CCTCCTC: 2 - ['hsa-miR-765' 'hsa-miR-11181-3p']
# CTCCGAA: 2 - ['hsa-miR-3188']
# TCAAGAA: 2 - ['hsa-miR-5584-3p']
# GGCCTGT: 2 - ['hsa-miR-4442']
# CGTTTTC: 2 - ['hsa-miR-548f-5p' 'hsa-miR-548g-5p' 'hsa-miR-548x-5p' 'hsa-miR-548aj-5p']
# ACGTGGA: 2 - ['hsa-miR-500a-3p']
# AGCATGG: 2 - ['hsa-miR-126-3p']
# CTTCTTA: 2 - ['hsa-miR-10522-5p']
# CTTAAGA: 2 - ['hsa-miR-10393-5p']
# ACATGTA: 2 - ['hsa-miR-493-5p']
# AGGACAT: 2 - ['hsa-miR-486-5p']
# TGGAGAG: 2 - ['hsa-miR-6800-3p']
# ATCCTAA: 2 - ['hsa-miR-3159']
# CCTAAAA: 2 - ['hsa-miR-1290']
# GTCACTG: 2 - ['hsa-miR-5190']
# CTGTAGT: 2 - ['hsa-miR-3913-3p']
# AGTTTGG: 2 - ['hsa-miR-6715b-3p']
# GTTTGGT: 2 - ['hsa-miR-6715a-3p']
# TGACAAA: 2 - ['hsa-miR-452-5p' 'hsa-miR-4676-3p' 'hsa-miR-892c-3p']
# AAAAAGT: 2 - ['hsa-miR-335-3p']
# ACATCCT: 2 - ['hsa-miR-8065']
# AGTGACA: 2 - ['hsa-miR-1208']
# ACTCTGT: 2 - ['hsa-miR-4524a-3p']
# TTTATCT: 2 - ['hsa-miR-3121-3p']
# ATGCATC: 2 - ['hsa-miR-1277-3p']
# TTTAGTT: 2 - ['hsa-miR-551b-5p']
# AAGGTGA: 2 - ['hsa-miR-6509-3p']
# TTCTGAG: 2 - ['hsa-miR-4432']
# AACCAAG: 2 - ['hsa-miR-659-3p']
# TTGTTTA: 2 - ['hsa-miR-7-1-3p' 'hsa-miR-7-2-3p']
# ATTGTGA: 2 - ['hsa-miR-141-3p' 'hsa-miR-200a-3p']
# GTGACAG: 2 - ['hsa-miR-6760-3p']
# CCCTCCT: 2 - ['hsa-miR-7106-5p']
# GTATGAA: 2 - ['hsa-miR-1-5p']
# GGGAACA: 2 - ['hsa-miR-6780b-3p']
# CAGAATG: 2 - ['hsa-miR-200c-5p' 'hsa-miR-550a-3p']
# AGAATGA: 2 - ['hsa-miR-550b-3p']
# TACATTG: 2 - ['hsa-miR-379-3p' 'hsa-miR-411-3p']
# ACATTGT: 2 - ['hsa-miR-194-5p']
# GAGTCAG: 2 - ['hsa-miR-4264']
# AGTCAGT: 2 - ['hsa-miR-4704-3p']
# TTGTTGT: 2 - ['hsa-miR-196a-1-3p']
# TATATAT: 2 - ['hsa-miR-5011-5p']
# TTAAGAG: 2 - ['hsa-miR-5571-5p']
# AAGAGGT: 2 - ['hsa-miR-515-5p' 'hsa-miR-519e-5p']
# TTAATAA: 2 - ['hsa-miR-944']
# CCCAGAA: 2 - ['hsa-miR-193a-5p']
# CTCCTCT: 2 - ['hsa-miR-3150b-3p' 'hsa-miR-4784']
# TTTTCAT: 2 - ['hsa-miR-548n']
# TTTCATT: 2 - ['hsa-miR-559' 'hsa-miR-548b-5p' 'hsa-miR-548a-5p' 'hsa-miR-548c-5p'
#  'hsa-miR-548d-5p' 'hsa-miR-548j-5p' 'hsa-miR-548h-5p' 'hsa-miR-548i'
#  'hsa-miR-548w' 'hsa-miR-548y' 'hsa-miR-548o-5p' 'hsa-miR-548ab'
#  'hsa-miR-548ad-5p' 'hsa-miR-548ae-5p' 'hsa-miR-548ak' 'hsa-miR-548am-5p'
#  'hsa-miR-548ap-5p' 'hsa-miR-548aq-5p' 'hsa-miR-548ar-5p'
#  'hsa-miR-548as-5p' 'hsa-miR-548au-5p' 'hsa-miR-548ay-5p'
#  'hsa-miR-548bb-5p']
# TTTTGCA: 2 - ['hsa-miR-424-3p']
# CTCTTTA: 2 - ['hsa-miR-539-5p']
# ACACTGG: 2 - ['hsa-miR-6808-3p' 'hsa-miR-7973']
# ACTTTCC: 2 - ['hsa-miR-488-3p']
# TTTGGCA: 2 - ['hsa-miR-1537-3p']
# AAAGTCA: 2 - ['hsa-miR-30a-3p' 'hsa-miR-30d-3p' 'hsa-miR-30e-3p']
# AGTCACA: 2 - ['hsa-miR-6733-3p']
# CACAGAA: 2 - ['hsa-miR-4711-3p']
# TCAAGAT: 2 - ['hsa-miR-3168']
# ATCAGGG: 2 - ['hsa-miR-2114-5p']
# ATGTCTA: 2 - ['hsa-miR-5683']
# ATGTACA: 2 - ['hsa-miR-4666a-5p']
# AACAGGA: 2 - ['hsa-miR-2355-3p']
# AGGCTCG: 2 - ['hsa-miR-615-3p']
# AAATTCT: 2 - ['hsa-miR-3658']
# AATCAGA: 2 - ['hsa-miR-4474-5p']
# TATTATG: 2 - ['hsa-miR-369-3p']
# ACCTTCT: 2 - ['hsa-miR-7-5p']
# AGAGTGA: 2 - ['hsa-miR-1304-3p']
# TTGGACA: 2 - ['hsa-miR-649']
# AACACTG: 2 - ['hsa-miR-758-3p']
# AATAAGT: 2 - ['hsa-miR-12123']
# CAACATG: 1 - ['hsa-miR-3613-5p']
# ATGCCTG: 1 - ['hsa-miR-4788']
# CCAAACA: 1 - ['hsa-miR-5087']
# TCACTAA: 1 - ['hsa-miR-8062']
# TTGTCAG: 1 - ['hsa-miR-212-3p' 'hsa-miR-132-3p']
# GTCAGTG: 1 - ['hsa-miR-4704-3p']
# ATGTACC: 1 - ['hsa-miR-4802-3p']
# TACCATG: 1 - ['hsa-miR-5579-5p']
# ACAAAGC: 1 - ['hsa-miR-5705']
# AACACAC: 1 - ['hsa-miR-6818-5p']
# ACATCAC: 1 - ['hsa-miR-142-3p']
# CATCACA: 1 - ['hsa-miR-142-3p']
# AGACAGA: 1 - ['hsa-miR-6888-3p']
# GACAGAC: 1 - ['hsa-miR-3120-5p']
# ACAATTA: 1 - ['hsa-miR-2053']
# AGGCAAA: 1 - ['hsa-miR-1468-5p']
# CAAAACG: 1 - ['hsa-miR-19a-5p' 'hsa-miR-19b-1-5p' 'hsa-miR-19b-2-5p']
# AAAACGT: 1 - ['hsa-miR-507' 'hsa-miR-450b-5p' 'hsa-miR-3680-3p']
# AAACGTC: 1 - ['hsa-miR-6516-5p']
# AACGTCG: 1 - ['hsa-miR-1301-3p' 'hsa-miR-5047']
# ACGTCGA: 1 - ['hsa-miR-1301-3p' 'hsa-miR-4660' 'hsa-miR-5047']
# AAAGGGA: 1 - ['hsa-miR-4446-5p' 'hsa-miR-4755-5p' 'hsa-miR-5006-3p']
# AAGGGAA: 1 - ['hsa-miR-204-5p' 'hsa-miR-211-5p' 'hsa-miR-4755-5p' 'hsa-miR-5006-3p']
# AGGGAAA: 1 - ['hsa-miR-204-5p' 'hsa-miR-211-5p']
# TACATTA: 1 - ['hsa-miR-380-3p']
# AGATTTA: 1 - ['hsa-miR-4799-5p']
# AAGACAG: 1 - ['hsa-miR-4743-3p']
# AGACAGT: 1 - ['hsa-miR-215-3p']
# AGTCCCA: 1 - ['hsa-miR-6823-5p']
# TCCCATC: 1 - ['hsa-miR-6755-5p']
# CAAAACT: 1 - ['hsa-miR-2052']
# AAACTCC: 1 - ['hsa-miR-1304-5p']
# AACTCCT: 1 - ['hsa-miR-3915' 'hsa-miR-4689']
# ACTCCTG: 1 - ['hsa-miR-1224-5p' 'hsa-miR-5004-5p']
# CTCCTGT: 1 - ['hsa-miR-5004-5p']
# AATCCGA: 1 - ['hsa-miR-12116']
# CGACCAC: 1 - ['hsa-miR-138-5p']
# GACCACT: 1 - ['hsa-miR-4299']
# AGCACCG: 1 - ['hsa-miR-1204']
# TCCACCT: 1 - ['hsa-miR-12114']
# CACCTGG: 1 - ['hsa-miR-4800-5p']
# CTGTGCC: 1 - ['hsa-miR-4462']
# AAACATA: 1 - ['hsa-miR-3149']
# TTTCCAT: 1 - ['hsa-miR-548m']
# ATCACCA: 1 - ['hsa-miR-4460' 'hsa-miR-203b-5p' 'hsa-miR-6718-5p']
# CACCATC: 1 - ['hsa-miR-4536-5p']
# ACCATCT: 1 - ['hsa-miR-379-5p' 'hsa-miR-4451']
# CCATCTG: 1 - ['hsa-miR-379-5p' 'hsa-miR-3529-5p']
# CAGACGG: 1 - ['hsa-miR-346']
# AGACGGA: 1 - ['hsa-miR-5001-3p']
# ACGGATG: 1 - ['hsa-miR-24-1-5p' 'hsa-miR-24-2-5p']
# GACCTGA: 1 - ['hsa-miR-378a-3p' 'hsa-miR-422a' 'hsa-miR-378d' 'hsa-miR-378b'
#  'hsa-miR-378c' 'hsa-miR-378e' 'hsa-miR-378f' 'hsa-miR-378h'
#  'hsa-miR-378i']
# CCTGATC: 1 - ['hsa-miR-6503-3p']
# TGATCAT: 1 - ['hsa-miR-3923']
# GATCATT: 1 - ['hsa-miR-628-3p']
# AGCTGGC: 1 - ['hsa-miR-1307-5p']
# TTCTGGC: 1 - ['hsa-miR-548ao-3p']
# CTGGGGA: 1 - ['hsa-miR-6846-3p']
# AAGGTGT: 1 - ['hsa-miR-3692-3p']
# CTGGGGG: 1 - ['hsa-miR-6859-3p']
# CTGTGAT: 1 - ['hsa-miR-3117-5p']
# GAGGGTT: 1 - ['hsa-miR-150-5p']
# AGGGTTC: 1 - ['hsa-miR-6814-5p']
# GGGTTCC: 1 - ['hsa-miR-6814-5p']
# TTCCTGT: 1 - ['hsa-miR-8080']
# AAGTCCA: 1 - ['hsa-miR-11399']
# CCTCCCT: 1 - ['hsa-miR-1249-5p' 'hsa-miR-6797-5p']
# CTCCCTG: 1 - ['hsa-miR-3126-5p' 'hsa-miR-6875-5p']
# GAAGAAG: 1 - ['hsa-miR-4778-3p']
# AAGAAGA: 1 - ['hsa-miR-4659a-3p' 'hsa-miR-4659b-3p']
# AGAAGAG: 1 - ['hsa-miR-942-5p']
# GAAGAGA: 1 - ['hsa-miR-942-5p']
# AGAGACT: 1 - ['hsa-miR-3921' 'hsa-miR-4653-5p']
# GAGACTC: 1 - ['hsa-miR-3921' 'hsa-miR-4653-5p']
# AGACTCT: 1 - ['hsa-miR-6761-5p']
# GACTCTT: 1 - ['hsa-miR-4251']
# ACTCACA: 1 - ['hsa-miR-574-5p' 'hsa-miR-3659' 'hsa-miR-4658' 'hsa-miR-6790-5p']
# GAAAAGA: 1 - ['hsa-miR-627-3p']
# AAGAGTT: 1 - ['hsa-miR-513c-5p' 'hsa-miR-514b-5p']
# GAACTTC: 1 - ['hsa-miR-4635']
# ATGGACC: 1 - ['hsa-miR-7851-3p']
# TGGACCT: 1 - ['hsa-miR-619-3p']
# TAGTACC: 1 - ['hsa-miR-2681-3p']
# ACCCACT: 1 - ['hsa-miR-1262' 'hsa-miR-4701-3p' 'hsa-miR-6736-5p']
# ACTGAGA: 1 - ['hsa-miR-4522']
# AGATTTC: 1 - ['hsa-miR-4744']
# GATTTCC: 1 - ['hsa-miR-4509']
# CCACGCC: 1 - ['hsa-miR-675-5p' 'hsa-miR-4466']
# CGAAGGA: 1 - ['hsa-miR-516b-3p' 'hsa-miR-516a-3p' 'hsa-miR-7162-5p']
# AGGACAG: 1 - ['hsa-miR-5699-3p' 'hsa-miR-6748-3p']
# TGCCCTT: 1 - ['hsa-miR-4681']
# TTAAATC: 1 - ['hsa-miR-32-3p']
# CTACCAA: 1 - ['hsa-miR-8069']
# GCCGAGA: 1 - ['hsa-miR-6741-3p']
# AGAAAAG: 1 - ['hsa-miR-627-3p']
# CTGATTG: 1 - ['hsa-miR-6831-3p']
# TGTGTAT: 1 - ['hsa-miR-4789-3p']
# ATATTTT: 1 - ['hsa-miR-3163']
# ACGCACC: 1 - ['hsa-miR-6821-5p']
# CGCACCC: 1 - ['hsa-miR-6853-5p']
# CACCCCC: 1 - ['hsa-miR-4447' 'hsa-miR-4472']
# ACCCCCC: 1 - ['hsa-miR-6795-5p' 'hsa-miR-6887-5p' 'hsa-miR-7109-5p']
# AACTCCC: 1 - ['hsa-miR-6734-5p']
# ACTCCCA: 1 - ['hsa-miR-6804-5p']
# ACTGGCT: 1 - ['hsa-miR-29c-5p']
# CTCTGTC: 1 - ['hsa-miR-4524a-3p']
# GAGTAAG: 1 - ['hsa-miR-6758-3p']
# AAGAAAC: 1 - ['hsa-miR-6844']
# CTCTGGA: 1 - ['hsa-miR-769-5p']
# AACTTGA: 1 - ['hsa-miR-203b-3p']
# CGGTGAC: 1 - ['hsa-miR-4252']
# GGTGACT: 1 - ['hsa-miR-181a-2-3p']
# ACTTCCG: 1 - ['hsa-miR-6126']
# ATCAGGA: 1 - ['hsa-miR-4540']
# CTAGAGT: 1 - ['hsa-miR-4695-3p']
# CACAAGT: 1 - ['hsa-miR-124-5p']
# TTTTAGG: 1 - ['hsa-miR-4668-3p']
# AGGAGAC: 1 - ['hsa-miR-6780a-3p']
# AGACCGA: 1 - ['hsa-miR-149-5p' 'hsa-miR-3064-5p' 'hsa-miR-4794' 'hsa-miR-6504-5p'
#  'hsa-miR-3085-3p']
# ACCGAAG: 1 - ['hsa-miR-6815-3p']
# TCCGCAG: 1 - ['hsa-miR-3186-5p']
# AACCTGC: 1 - ['hsa-miR-4804-5p']
# ACCTGCC: 1 - ['hsa-miR-184' 'hsa-miR-4804-5p']
# CCTGCCT: 1 - ['hsa-miR-184']
# TGTGTCC: 1 - ['hsa-miR-6768-5p']
# CCTGGAA: 1 - ['hsa-miR-659-5p']
# GGAACTG: 1 - ['hsa-miR-10397-5p']
# GCCGGGG: 1 - ['hsa-miR-10392-3p']
# CGGGGCC: 1 - ['hsa-miR-10396a-3p' 'hsa-miR-10396b-3p']
# AGGGATG: 1 - ['hsa-miR-3162-3p']
# AACAGGG: 1 - ['hsa-miR-4646-3p']
# AGTGTGG: 1 - ['hsa-miR-1228-3p']
# GAATGTC: 1 - ['hsa-miR-600']
# CTCAGAA: 1 - ['hsa-miR-924']
# ATTCCAC: 1 - ['hsa-miR-18a-5p' 'hsa-miR-18b-5p']
# CACTGTC: 1 - ['hsa-miR-542-3p']
# GTCAAGA: 1 - ['hsa-miR-4277']
# GTCACCC: 1 - ['hsa-miR-194-3p']
# CACCCTG: 1 - ['hsa-miR-4648']
# TTTTCAC: 1 - ['hsa-miR-548t-5p' 'hsa-miR-548az-5p']
# TTTCACG: 1 - ['hsa-miR-17-5p' 'hsa-miR-20a-5p' 'hsa-miR-93-5p' 'hsa-miR-106a-5p'
#  'hsa-miR-106b-5p' 'hsa-miR-20b-5p' 'hsa-miR-526b-3p' 'hsa-miR-519d-3p']
# TTCACGT: 1 - ['hsa-miR-519c-3p' 'hsa-miR-519b-3p' 'hsa-miR-519a-3p']
# ATGGGAG: 1 - ['hsa-miR-7848-3p']
# GCCACGA: 1 - ['hsa-miR-1250-5p']
# ACGACCC: 1 - ['hsa-miR-4731-5p']
# GACCCTT: 1 - ['hsa-miR-204-3p' 'hsa-miR-4646-5p']
# GAGGGAA: 1 - ['hsa-miR-4287' 'hsa-miR-4685-3p']
# AGGGAAG: 1 - ['hsa-miR-5088-3p']
# GGAAGGA: 1 - ['hsa-miR-3667-3p']
# AGGCCCT: 1 - ['hsa-miR-4497']
# CCCTTCC: 1 - ['hsa-miR-4747-5p' 'hsa-miR-5196-5p']
# CCTTCCT: 1 - ['hsa-miR-4533']
# GGACATG: 1 - ['hsa-miR-486-5p']
# TGGTGAA: 1 - ['hsa-miR-1255b-2-3p']
# GGAACGT: 1 - ['hsa-miR-6841-3p']
# AACGTGA: 1 - ['hsa-miR-4325' 'hsa-miR-7703']
# ACGTGAG: 1 - ['hsa-miR-7703']
# GTGAGGA: 1 - ['hsa-miR-483-3p']
# AGGAGAG: 1 - ['hsa-miR-7111-3p']
# TTTTGGC: 1 - ['hsa-miR-548at-3p' 'hsa-miR-548ay-3p']
# GGCACGT: 1 - ['hsa-miR-1973']
# TGTGTGG: 1 - ['hsa-miR-362-3p' 'hsa-miR-329-3p']
# CCCACCT: 1 - ['hsa-miR-363-5p' 'hsa-miR-6745']
# CACCTGT: 1 - ['hsa-miR-3138']
# TGAGTTT: 1 - ['hsa-miR-888-5p']
# GAGTTTA: 1 - ['hsa-miR-372-5p']
# TTTAAAG: 1 - ['hsa-miR-513a-3p' 'hsa-miR-513c-3p' 'hsa-miR-3606-3p']
# TAAATGA: 1 - ['hsa-miR-4699-3p']
# AGAGGGT: 1 - ['hsa-miR-150-5p' 'hsa-miR-4713-5p']
# GGTCACA: 1 - ['hsa-miR-199a-5p' 'hsa-miR-199b-5p']
# AAATCCT: 1 - ['hsa-miR-651-5p']
# AATCCTA: 1 - ['hsa-miR-651-5p']
# AGTGAGG: 1 - ['hsa-miR-483-3p']
# TGTCATG: 1 - ['hsa-miR-101-3p']
# ATTGACC: 1 - ['hsa-miR-582-3p']
# GACCCCT: 1 - ['hsa-miR-4667-5p' 'hsa-miR-4700-5p' 'hsa-miR-8089']
# ACCCCTG: 1 - ['hsa-miR-3191-3p' 'hsa-miR-6810-5p']
# TCTTGTC: 1 - ['hsa-miR-4773']
# AACCTGA: 1 - ['hsa-miR-4529-3p' 'hsa-miR-5009-5p']
# ACCTGAC: 1 - ['hsa-miR-1269a' 'hsa-miR-1288-3p' 'hsa-miR-1269b']
# AAAAGTT: 1 - ['hsa-miR-1305']
# AAAGTTC: 1 - ['hsa-miR-498-5p']
# GTGTGGA: 1 - ['hsa-miR-1228-3p']
# ATGGGGG: 1 - ['hsa-miR-6798-3p']
# ATTAAAA: 1 - ['hsa-miR-590-3p' 'hsa-miR-4775']
# CTATAAA: 1 - ['hsa-miR-3145-3p']
# AGAAGTG: 1 - ['hsa-miR-6754-3p']
# AAGTGAC: 1 - ['hsa-miR-653-3p']
# TGACATC: 1 - ['hsa-miR-1183']
# CTTCCAG: 1 - ['hsa-miR-493-3p']
# TTCCAGT: 1 - ['hsa-miR-3974']
# GTTTAGA: 1 - ['hsa-miR-4762-5p']
# TTATATA: 1 - ['hsa-miR-1277-5p']
# ATATACC: 1 - ['hsa-miR-8076']
# ATACCAT: 1 - ['hsa-miR-5579-5p']
# ATTTATC: 1 - ['hsa-miR-3121-3p']
# AACTTTG: 1 - ['hsa-miR-510-3p']
# ATATTTC: 1 - ['hsa-miR-340-5p']
# ATTTCGA: 1 - ['hsa-miR-9-3p']
# ATCTCAG: 1 - ['hsa-miR-5007-5p']
# GTTTTTT: 1 - ['hsa-miR-3613-3p']
# AATTGTA: 1 - ['hsa-miR-302c-5p']
# ATTGTAT: 1 - ['hsa-miR-4803']
# CCTATAC: 1 - ['hsa-miR-3201' 'hsa-miR-4791']
# CTATACA: 1 - ['hsa-miR-190a-5p' 'hsa-miR-190b-5p']
# ATACACT: 1 - ['hsa-miR-4501']
# ACACTAT: 1 - ['hsa-miR-3689a-5p' 'hsa-miR-3689b-5p' 'hsa-miR-3689e' 'hsa-miR-3689f']
# ATCGTTT: 1 - ['hsa-miR-548p']
# TCGTTTT: 1 - ['hsa-miR-548p']
# TTGAGAT: 1 - ['hsa-miR-618']
# TATCTCT: 1 - ['hsa-miR-3976']
# TCTCTTG: 1 - ['hsa-miR-3925-5p']
# CTCTTGA: 1 - ['hsa-miR-146a-5p' 'hsa-miR-146b-5p' 'hsa-miR-7153-5p']
# AGGTGAG: 1 - ['hsa-miR-6777-3p']
# GGTGAGA: 1 - ['hsa-miR-6777-3p']
# AGATAAG: 1 - ['hsa-miR-6731-3p']
# CTACCTA: 1 - ['hsa-miR-3134']
# TACCTAA: 1 - ['hsa-miR-1246']
# CCTAAGA: 1 - ['hsa-miR-4320']
# GATGTCA: 1 - ['hsa-miR-139-5p']
# CACGTCA: 1 - ['hsa-miR-143-5p']
# ATTGTTT: 1 - ['hsa-miR-5688']
# TTGTGAC: 1 - ['hsa-miR-141-3p' 'hsa-miR-200a-3p']
# TCCCTTT: 1 - ['hsa-miR-5584-5p']
# CTTTGAC: 1 - ['hsa-miR-4738-3p']
# TTTCTTG: 1 - ['hsa-miR-3133']
# TTCTTGA: 1 - ['hsa-miR-4511']
# CCTCGTC: 1 - ['hsa-miR-6081']
# TCGTCCC: 1 - ['hsa-miR-6510-5p']
# GTCCCTG: 1 - ['hsa-miR-211-3p']
# TCATGGT: 1 - ['hsa-miR-624-5p']
# ACCCATG: 1 - ['hsa-miR-1225-5p']
# AAATCTA: 1 - ['hsa-miR-4760-5p']
# TTAGAGA: 1 - ['hsa-miR-216b-5p']
# AGAGAGT: 1 - ['hsa-miR-12125']
# TACGTGG: 1 - ['hsa-miR-501-3p' 'hsa-miR-502-3p']
# TTCAACA: 1 - ['hsa-miR-382-5p']
# AACACAG: 1 - ['hsa-miR-592' 'hsa-miR-599']
# ACAGACC: 1 - ['hsa-miR-1231']
# AGACCCA: 1 - ['hsa-miR-6776-5p']
# GACCCAC: 1 - ['hsa-miR-6776-5p']
# ACCCACC: 1 - ['hsa-miR-1293' 'hsa-miR-6745']
# CCCACCC: 1 - ['hsa-miR-6756-5p' 'hsa-miR-6766-5p']
# CCACCCA: 1 - ['hsa-miR-6769a-5p' 'hsa-miR-6769b-5p']
# AGCCCTC: 1 - ['hsa-miR-6771-5p']
# CCTCCTG: 1 - ['hsa-miR-7154-3p']
# CCTCCTT: 1 - ['hsa-miR-766-5p']
# TCCTTCC: 1 - ['hsa-miR-4476' 'hsa-miR-6876-5p']
# TTCCGCG: 1 - ['hsa-miR-525-3p' 'hsa-miR-524-3p']
# CCGCGGG: 1 - ['hsa-miR-6789-3p']
# CTCATGG: 1 - ['hsa-miR-1911-5p']
# TCAGGGT: 1 - ['hsa-miR-5588-3p']
# TCCTGAA: 1 - ['hsa-miR-8083']
# ATGCAGT: 1 - ['hsa-miR-598-3p']
# AGTGGTG: 1 - ['hsa-miR-197-3p']
# ACGCTCC: 1 - ['hsa-miR-4737']
# CGCTCCA: 1 - ['hsa-miR-381-5p']
# CCACCAA: 1 - ['hsa-miR-876-3p']
# CACCAAG: 1 - ['hsa-miR-203a-5p']
# ACCAAGA: 1 - ['hsa-miR-182-3p' 'hsa-miR-597-3p']
# AGGAAAC: 1 - ['hsa-miR-3121-5p']
# AACCTGT: 1 - ['hsa-miR-4520-3p' 'hsa-miR-4520-2-3p']
# AGACCTC: 1 - ['hsa-miR-516b-5p']
# ACCTCCC: 1 - ['hsa-miR-6515-5p']
# CTCCCCG: 1 - ['hsa-miR-423-5p' 'hsa-miR-3184-5p']
# CCCCGGC: 1 - ['hsa-miR-128-1-5p' 'hsa-miR-128-2-5p']
# CGGCGGG: 1 - ['hsa-miR-4632-3p']
# GGGCCTC: 1 - ['hsa-miR-10398-3p']
# CCTCAGG: 1 - ['hsa-miR-1289']
# AGGGAAC: 1 - ['hsa-miR-623' 'hsa-miR-6780b-3p']
# AGACCTT: 1 - ['hsa-miR-1299']
# ACCTTTG: 1 - ['hsa-miR-147b-5p']
# AATATTA: 1 - ['hsa-miR-374a-5p']
# ATATTAT: 1 - ['hsa-miR-374a-5p' 'hsa-miR-374b-5p']
# TATTTTA: 1 - ['hsa-miR-3163']
# ATATGGA: 1 - ['hsa-miR-875-5p' 'hsa-miR-3144-3p']
# ATCCAAT: 1 - ['hsa-miR-154-5p']
# CAATCCT: 1 - ['hsa-miR-1258']
# ATCCTGT: 1 - ['hsa-miR-1197']
# ATTTTAA: 1 - ['hsa-miR-4282']
# ATGGAGT: 1 - ['hsa-miR-4777-3p']
# TGCAGTA: 1 - ['hsa-miR-598-3p']
# ACGTGGT: 1 - ['hsa-miR-767-5p']
# CGTGGTA: 1 - ['hsa-miR-767-5p']
# ATCCTCC: 1 - ['hsa-miR-4266' 'hsa-miR-4779']
# ATGAAGA: 1 - ['hsa-miR-3682-5p']
# CGTGGAC: 1 - ['hsa-miR-6804-3p']
# ACGTTTT: 1 - ['hsa-miR-548f-5p' 'hsa-miR-548g-5p' 'hsa-miR-548x-5p' 'hsa-miR-548aj-5p'
#  'hsa-miR-548aw']
# ACGGGAT: 1 - ['hsa-miR-18b-3p' 'hsa-miR-3157-3p']
# CGGGATT: 1 - ['hsa-miR-18b-3p']
# ATATATA: 1 - ['hsa-miR-190a-3p' 'hsa-miR-5011-5p']
# GAGGTCA: 1 - ['hsa-miR-3925-3p']
# AGGTCAC: 1 - ['hsa-miR-1825']
# GGTCACG: 1 - ['hsa-miR-1825']
# TCACGGG: 1 - ['hsa-miR-371b-3p']
# TTTTGCT: 1 - ['hsa-miR-548ad-3p']
# ATAACAG: 1 - ['hsa-miR-5701']
# TGTGCCC: 1 - ['hsa-miR-602']
# CTCTTGG: 1 - ['hsa-miR-589-5p']
# TGGCCCC: 1 - ['hsa-miR-4655-5p']
# AACATGT: 1 - ['hsa-miR-493-5p']
# ACATGTT: 1 - ['hsa-let-7c-3p']
# CTCAACT: 1 - ['hsa-miR-219a-1-3p']
# ACTAGTC: 1 - ['hsa-miR-4772-5p']
# AGTCATT: 1 - ['hsa-miR-545-5p']
# GTCATTT: 1 - ['hsa-miR-545-5p']
# TTTCTCC: 1 - ['hsa-miR-583']
# CCTCTTC: 1 - ['hsa-miR-4434' 'hsa-miR-4516' 'hsa-miR-5703']
# CTCTTCT: 1 - ['hsa-miR-1253']
# TTTTTCA: 1 - ['hsa-miR-12136']
# ACAGAGA: 1 - ['hsa-miR-593-3p' 'hsa-miR-6818-3p' 'hsa-miR-6895-3p']
# ATCCCTA: 1 - ['hsa-miR-6757-5p']
# AAGAGGG: 1 - ['hsa-miR-629-3p' 'hsa-miR-4713-5p']
# TCACATC: 1 - ['hsa-miR-4280']
# ATCTGCA: 1 - ['hsa-miR-6863']
# ATGAAAA: 1 - ['hsa-miR-5003-3p']
# AAAAAAC: 1 - ['hsa-miR-9983-3p']
# GTCCTCT: 1 - ['hsa-miR-4768-3p']
# ACTCCTC: 1 - ['hsa-miR-3150b-3p' 'hsa-miR-4689' 'hsa-miR-4784' 'hsa-miR-6858-5p']
# TCTTTAC: 1 - ['hsa-miR-5680']
# TTACACT: 1 - ['hsa-miR-8066']
# TACACTG: 1 - ['hsa-miR-4501']
# GCCAGGG: 1 - ['hsa-miR-4746-5p']
# TTTCCAA: 1 - ['hsa-miR-12135']
# AAATTGG: 1 - ['hsa-miR-552-5p']
# GGACAAG: 1 - ['hsa-miR-1266-3p']
# GGGCTCT: 1 - ['hsa-miR-4740-3p']
# AAAGGAG: 1 - ['hsa-miR-670-3p' 'hsa-miR-3059-5p']
# AAGGAGA: 1 - ['hsa-miR-3059-5p']
# AGGAGAA: 1 - ['hsa-miR-877-3p' 'hsa-miR-6881-3p']
# AGAAGAA: 1 - ['hsa-miR-4778-3p']
# AAGAACA: 1 - ['hsa-miR-578']
# AACATCT: 1 - ['hsa-miR-3674']
# GAACCTC: 1 - ['hsa-miR-432-5p']
# AACCTCC: 1 - ['hsa-miR-4443' 'hsa-miR-6515-5p']
# ACCTCCT: 1 - ['hsa-miR-765']
# CCCTCCC: 1 - ['hsa-miR-149-3p' 'hsa-miR-4728-5p' 'hsa-miR-6785-5p' 'hsa-miR-6883-5p']
# TCCCAGT: 1 - ['hsa-miR-1178-5p']
# AGTCCCT: 1 - ['hsa-miR-4270' 'hsa-miR-12128']
# GTCCCTC: 1 - ['hsa-miR-4270' 'hsa-miR-4441' 'hsa-miR-6754-5p']
# CCCTCGC: 1 - ['hsa-miR-6090']
# ACTCCGC: 1 - ['hsa-miR-6765-5p']
# CAAGAGA: 1 - ['hsa-miR-2117']
# AAGAGAG: 1 - ['hsa-miR-4768-5p' 'hsa-miR-6833-3p' 'hsa-miR-6873-3p']
# ACAGGGT: 1 - ['hsa-miR-4433b-5p']
# GGTCTAT: 1 - ['hsa-miR-488-5p']
# GGTCGTC: 1 - ['hsa-miR-4530']
# GTCGTCT: 1 - ['hsa-miR-922']
# CGTCTCC: 1 - ['hsa-miR-2467-3p']
# CCGAAGA: 1 - ['hsa-miR-6815-3p']
# ACTCTGG: 1 - ['hsa-miR-769-5p' 'hsa-miR-4786-5p']
# TAAAGTC: 1 - ['hsa-miR-205-3p']
# GTCACAG: 1 - ['hsa-miR-6733-3p']
# AAGGAAG: 1 - ['hsa-miR-6868-3p']
# ACCTCAA: 1 - ['hsa-miR-4653-3p']
# CCTCAAT: 1 - ['hsa-miR-4653-3p']
# CTCAATT: 1 - ['hsa-miR-4424']
# AAACAAG: 1 - ['hsa-miR-375-3p']
# AACAAGA: 1 - ['hsa-miR-4677-5p' 'hsa-miR-6739-3p' 'hsa-miR-7156-5p']
# TCTCTCC: 1 - ['hsa-miR-6758-5p' 'hsa-miR-6856-5p']
# CACTTAC: 1 - ['hsa-miR-1257']
# ACTTACC: 1 - ['hsa-miR-4790-3p']
# ACCTCTC: 1 - ['hsa-miR-185-5p' 'hsa-miR-4306' 'hsa-miR-4644']
# CCTCTCT: 1 - ['hsa-miR-185-5p' 'hsa-miR-4306' 'hsa-miR-4644']
# TGTGTTC: 1 - ['hsa-miR-4731-3p' 'hsa-miR-4801']
# TGTTCAG: 1 - ['hsa-miR-6882-5p']
# CAGATGT: 1 - ['hsa-miR-3618']
# GCCTTCC: 1 - ['hsa-miR-6125']
# TTCCATT: 1 - ['hsa-miR-570-5p' 'hsa-miR-548ag' 'hsa-miR-548ai' 'hsa-miR-548ba']
# ATATGTG: 1 - ['hsa-miR-4789-5p']
# TGTGATC: 1 - ['hsa-miR-4704-5p']
# ATCATCT: 1 - ['hsa-miR-411-5p']
# CATCTAA: 1 - ['hsa-miR-376a-2-5p']
# CAGTGGG: 1 - ['hsa-miR-6879-3p']
# AGTGGGA: 1 - ['hsa-miR-3620-3p']
# ATTAGGA: 1 - ['hsa-miR-500a-5p']
# TTAGGAA: 1 - ['hsa-miR-500a-5p']
# GAGAGGA: 1 - ['hsa-miR-6845-3p']
# AGAGGAG: 1 - ['hsa-miR-4279']
# GTTATAA: 1 - ['hsa-miR-16-2-3p' 'hsa-miR-195-3p']
# TATAATA: 1 - ['hsa-miR-656-3p']
# ATAATAA: 1 - ['hsa-miR-4795-3p']
# TAATAAT: 1 - ['hsa-miR-126-5p']
# AAGATTA: 1 - ['hsa-miR-576-5p']
# GATTAAA: 1 - ['hsa-miR-4735-5p']
# GTAAATA: 1 - ['hsa-miR-4729']
# AATCAGG: 1 - ['hsa-miR-4540']
# TCCCAAC: 1 - ['hsa-miR-296-3p']
# CCCAACA: 1 - ['hsa-miR-12130']
# ACACATG: 1 - ['hsa-miR-3177-5p']
# CACATGT: 1 - ['hsa-miR-3177-5p']
# ACATGTC: 1 - ['hsa-let-7a-2-3p' 'hsa-let-7g-3p']
# TTTCACC: 1 - ['hsa-miR-4796-3p']
# TTCACCT: 1 - ['hsa-miR-12117']
# TCACCTC: 1 - ['hsa-miR-12115']
# CACCTCC: 1 - ['hsa-miR-7847-3p']
# ATCTATT: 1 - ['hsa-miR-577']
# TTGAGTG: 1 - ['hsa-miR-6750-3p']
# TGAGTGA: 1 - ['hsa-miR-3680-5p']
# AATAGTC: 1 - ['hsa-miR-361-5p' 'hsa-miR-374a-3p']
# ATAGTCT: 1 - ['hsa-miR-361-5p']
# GTCTCTA: 1 - ['hsa-miR-4756-3p']
# TCTATTT: 1 - ['hsa-miR-577']
# ACTTATC: 1 - ['hsa-miR-5585-3p']
# AGTTTAT: 1 - ['hsa-miR-3671']
# AACTTAA: 1 - ['hsa-miR-4452']
# CCAACTG: 1 - ['hsa-miR-380-5p' 'hsa-miR-563']
# TTTTTAG: 1 - ['hsa-miR-548c-3p']
# AGACTTT: 1 - ['hsa-miR-4766-5p']
# GACTTTC: 1 - ['hsa-miR-4766-5p']
# TTTCTTA: 1 - ['hsa-miR-186-5p']
# TTCTTAT: 1 - ['hsa-miR-6507-5p']
# ATCACTT: 1 - ['hsa-miR-3606-5p']
# AGTTAGT: 1 - ['hsa-miR-4705']
# TACACCT: 1 - ['hsa-miR-4491' 'hsa-miR-4657']
# ACACCTA: 1 - ['hsa-miR-4752']
# CACCTAC: 1 - ['hsa-miR-3691-5p']
# ACCTACT: 1 - ['hsa-miR-6744-5p']
# CCTACTC: 1 - ['hsa-miR-1255a' 'hsa-miR-1255b-5p']
# ATCAGAG: 1 - ['hsa-miR-4474-5p']
# AGAGAAA: 1 - ['hsa-miR-4753-3p']
# AAGCCAT: 1 - ['hsa-miR-4798-5p']
# CTAAGGA: 1 - ['hsa-miR-145-3p']
# TGGTGTC: 1 - ['hsa-miR-140-3p']
# CCAGACA: 1 - ['hsa-miR-6753-3p' 'hsa-miR-7107-3p']
# ACACACT: 1 - ['hsa-miR-6818-5p']
# AGATCTT: 1 - ['hsa-miR-6508-5p']
# TTTCAGG: 1 - ['hsa-miR-6507-3p']
# ATGGGAC: 1 - ['hsa-miR-10a-5p' 'hsa-miR-10b-5p']
# TGGGACA: 1 - ['hsa-miR-10a-5p' 'hsa-miR-10b-5p']
# ACATTTG: 1 - ['hsa-miR-30a-5p' 'hsa-miR-30c-5p' 'hsa-miR-30d-5p' 'hsa-miR-30b-5p'
#  'hsa-miR-30e-5p']
# CATTTGT: 1 - ['hsa-miR-30a-5p' 'hsa-miR-30c-5p' 'hsa-miR-30d-5p' 'hsa-miR-30b-5p'
#  'hsa-miR-30e-5p']
# AGGAAGA: 1 - ['hsa-miR-1237-3p' 'hsa-miR-6868-3p']
# GGAAGAA: 1 - ['hsa-miR-1248']
# GATCAGG: 1 - ['hsa-miR-554']
# TTCAGAA: 1 - ['hsa-miR-1264']
# GACCTGT: 1 - ['hsa-miR-4638-3p']
# GTCGATG: 1 - ['hsa-miR-5690']
# GCCTCTG: 1 - ['hsa-miR-5091']
# CCTCTGC: 1 - ['hsa-miR-139-3p']
# CGAAGAA: 1 - ['hsa-miR-103a-2-5p' 'hsa-miR-103a-1-5p']
# TGTGTGA: 1 - ['hsa-miR-603']
# GTGACAA: 1 - ['hsa-miR-1208']
# ATTTTGA: 1 - ['hsa-miR-548ar-3p' 'hsa-miR-5582-3p']
# TTTTGAA: 1 - ['hsa-miR-5582-3p']
# TTGTGGT: 1 - ['hsa-miR-21-3p' 'hsa-miR-122b-3p']
# ACGACCT: 1 - ['hsa-miR-1287-5p']
# CAGAGAC: 1 - ['hsa-miR-593-3p']
# AGACATC: 1 - ['hsa-miR-3137']
# GACATCA: 1 - ['hsa-miR-20b-3p']
# GCATGGC: 1 - ['hsa-miR-126-3p']
# AGTGCAG: 1 - ['hsa-miR-11401']
# CCGTTTG: 1 - ['hsa-miR-4470']
# GATATGT: 1 - ['hsa-miR-1284']
# ATATGTC: 1 - ['hsa-let-7f-2-3p' 'hsa-miR-1185-2-3p' 'hsa-miR-1185-1-3p']
# ATGGGTA: 1 - ['hsa-miR-660-5p' 'hsa-miR-5591-3p']
# ATTTAAA: 1 - ['hsa-miR-513a-3p' 'hsa-miR-513c-3p']
# AGTTTTA: 1 - ['hsa-miR-4698' 'hsa-miR-8063']
# ACTAACA: 1 - ['hsa-miR-219a-5p' 'hsa-miR-508-3p' 'hsa-miR-4782-3p' 'hsa-miR-6766-3p']
# CTAACAG: 1 - ['hsa-miR-219a-5p' 'hsa-miR-4782-3p' 'hsa-miR-6766-3p']
# ACAGGAT: 1 - ['hsa-miR-676-3p']
# AGGATAT: 1 - ['hsa-miR-337-3p']
# TAATGAC: 1 - ['hsa-miR-12132']
# AACCTTC: 1 - ['hsa-miR-6079']
# CCTTCTG: 1 - ['hsa-miR-7-5p']
# AGGGACA: 1 - ['hsa-miR-339-5p']
# ATTATGT: 1 - ['hsa-miR-655-3p' 'hsa-miR-374c-5p']
# ATACAGA: 1 - ['hsa-miR-654-3p']
# ACAGAAA: 1 - ['hsa-miR-511-5p' 'hsa-miR-6830-3p']
# GAGAGTG: 1 - ['hsa-miR-12125']
# TCCTTTA: 1 - ['hsa-miR-12124']
# TAGTCTT: 1 - ['hsa-miR-2115-3p']
# TGTTCCA: 1 - ['hsa-miR-624-3p']
# ATCATGA: 1 - ['hsa-miR-1278']
# TCTCACT: 1 - ['hsa-miR-5586-3p']
# ACTGGAT: 1 - ['hsa-miR-192-5p' 'hsa-miR-215-5p']
# TGAATGG: 1 - ['hsa-miR-9898']
# TGTACCG: 1 - ['hsa-miR-942-3p']
# ACCGGTT: 1 - ['hsa-miR-548s' 'hsa-miR-3926']
# CGGTTCA: 1 - ['hsa-miR-4480']
# GTTCATC: 1 - ['hsa-miR-5697']
# TCATCTG: 1 - ['hsa-miR-411-5p']
# ATCTGGA: 1 - ['hsa-miR-3684']
# ACTTCAA: 1 - ['hsa-miR-4670-3p']
# AGCAAAC: 1 - ['hsa-miR-1282']
# ATACCAA: 1 - ['hsa-miR-584-5p']
# TACCAAG: 1 - ['hsa-miR-218-2-3p']
# TGAGCAC: 1 - ['hsa-miR-4636']
# AGCACAG: 1 - ['hsa-miR-187-3p' 'hsa-miR-6774-3p']
# GCACAGA: 1 - ['hsa-miR-187-3p']
# ACAGAAG: 1 - ['hsa-miR-6740-3p']
# CAGAAGA: 1 - ['hsa-miR-6740-3p']
# GTGGAGG: 1 - ['hsa-miR-1306-5p']
# AAAATTC: 1 - ['hsa-miR-7856-5p']
# AATTCTG: 1 - ['hsa-miR-499a-5p']
# CTGAGAC: 1 - ['hsa-miR-4522']
# TGAGACT: 1 - ['hsa-miR-4714-5p']
# AGACTGT: 1 - ['hsa-miR-6719-3p']
# GACTGTA: 1 - ['hsa-miR-6719-3p']
# TGTAGTG: 1 - ['hsa-miR-499a-3p' 'hsa-miR-499b-3p']
# AATCCAT: 1 - ['hsa-miR-6509-5p']
# CACCTAA: 1 - ['hsa-miR-8056']
# ACCTAAA: 1 - ['hsa-miR-876-5p' 'hsa-miR-1290']
# ACCTTTT: 1 - ['hsa-miR-3148']
# ATTTCAT: 1 - ['hsa-miR-559']
# TCCCTCC: 1 - ['hsa-miR-1321' 'hsa-miR-4739' 'hsa-miR-4756-5p']
# GAATTTG: 1 - ['hsa-miR-302a-5p']
# GAGTGAC: 1 - ['hsa-miR-1304-3p']
# GACAGTG: 1 - ['hsa-miR-6773-3p']
# ACAGTGG: 1 - ['hsa-miR-6879-3p']
# TTTTGGG: 1 - ['hsa-miR-548as-3p']
# TTTGGGG: 1 - ['hsa-miR-6771-3p']
# TTTTGGT: 1 - ['hsa-miR-548t-3p' 'hsa-miR-548aa' 'hsa-miR-548ap-3p']
# TTTGGTG: 1 - ['hsa-miR-497-3p']
# TTGGTGG: 1 - ['hsa-miR-6776-3p']
# TATTATA: 1 - ['hsa-miR-5692c' 'hsa-miR-5692b']
# TTATACC: 1 - ['hsa-miR-5583-3p']
# TATACCT: 1 - ['hsa-miR-8076']
# ATACCTT: 1 - ['hsa-miR-3688-3p']
# ACCAAGG: 1 - ['hsa-miR-218-1-3p']
# GTTTTGA: 1 - ['hsa-miR-1323' 'hsa-miR-548o-3p']
# ACTGGGG: 1 - ['hsa-miR-6846-3p' 'hsa-miR-6859-3p']
# GTTATTT: 1 - ['hsa-miR-95-5p']
# ATTTTTG: 1 - ['hsa-miR-548x-3p' 'hsa-miR-548aj-3p']
# AAGTGTT: 1 - ['hsa-miR-513b-5p']
# AGTGTTT: 1 - ['hsa-miR-4719']
# TTTCATA: 1 - ['hsa-miR-548l']
# TTTACCT: 1 - ['hsa-miR-4694-3p']
# ACCTTCC: 1 - ['hsa-miR-3202' 'hsa-miR-4533']
# TGGCTGA: 1 - ['hsa-miR-6510-3p']
# ATTCTGC: 1 - ['hsa-miR-208a-3p' 'hsa-miR-208b-3p']
# ACACTGT: 1 - ['hsa-miR-542-3p' 'hsa-miR-4504']
# GTACACA: 1 - ['hsa-miR-10226']
# TACACAT: 1 - ['hsa-miR-511-3p']
# CACATAA: 1 - ['hsa-miR-223-5p']
# AAGGATA: 1 - ['hsa-miR-202-5p']
# AGGATAC: 1 - ['hsa-miR-202-5p']
# ACTTTAC: 1 - ['hsa-miR-203a-3p']
# AAGTAAG: 1 - ['hsa-miR-1298-5p']
# TAAGTCT: 1 - ['hsa-miR-892c-5p']
# GTCTCCA: 1 - ['hsa-miR-4257']
# ATAATGG: 1 - ['hsa-miR-556-3p']
# ACTTTGT: 1 - ['hsa-miR-494-3p']
# TTGTTTG: 1 - ['hsa-miR-495-3p' 'hsa-miR-5688']
# GTGTTGT: 1 - ['hsa-miR-5003-5p']
# AACTTTC: 1 - ['hsa-miR-488-3p']
# TTCCTTG: 1 - ['hsa-miR-12120']
# GTCTGTC: 1 - ['hsa-miR-1324']
# GTCTAGT: 1 - ['hsa-miR-1288-5p']
# ACAGTGT: 1 - ['hsa-miR-12122']

# %%
# top matching 7mer-A1s

seeds = find_seed_in_kmers(generate_kmers(sequence, 7), seed_kmers)

for kmer, count in seeds.items():
    if count != 0:
        possible_sequences = mirna_df.loc[(mirna_df['7mer-A1'] == kmer)]["name"].values
        print(f"{kmer}: {count} - {possible_sequences}")
# Out:
# ACACACA: 8 - ['hsa-miR-6867-5p']
# CACACAC: 6 - []
# ACAGAAT: 5 - ['hsa-miR-550a-3p']
# TGTTGTT: 4 - []
# GAAGTGA: 4 - []
# GGGCCCT: 4 - []
# CATTGTC: 3 - []
# ATTGTCA: 3 - ['hsa-miR-212-3p' 'hsa-miR-132-3p']
# GGGGAAG: 3 - []
# AACAGAG: 3 - ['hsa-miR-6818-3p']
# AGAGGGA: 3 - ['hsa-miR-4287' 'hsa-miR-4685-3p']
# AAGGACA: 3 - []
# AGAACCT: 3 - ['hsa-miR-432-5p']
# CCCTCCA: 3 - []
# ACTGTAG: 3 - []
# AAAGAAG: 3 - ['hsa-miR-4659a-3p' 'hsa-miR-4659b-3p']
# AAACCTG: 3 - ['hsa-miR-4520-2-3p']
# TGCATCT: 3 - []
# TTGTATT: 3 - []
# ATTCTGA: 3 - []
# GACCTTT: 3 - []
# TCAGGGA: 3 - []
# CTTTTGT: 3 - []
# AGTAAAT: 3 - ['hsa-miR-4729']
# ATGAATG: 3 - ['hsa-miR-9898']
# GATCTTT: 3 - []
# TTTATTA: 3 - []
# ATCAAGA: 3 - ['hsa-miR-5584-3p']
# TTTTAAA: 3 - []
# CCCCAAA: 2 - []
# CAAACAA: 2 - []
# AGTGATG: 2 - ['hsa-miR-4999-3p']
# AATAACA: 2 - ['hsa-miR-5701']
# ACATTAT: 2 - []
# TAAGACA: 2 - []
# CTCCACC: 2 - []
# CCACCTG: 2 - []
# ACCTGGA: 2 - ['hsa-miR-6861-3p']
# CTTTCCA: 2 - []
# CTGAAGA: 2 - []
# AAAGGAC: 2 - ['hsa-miR-7152-5p']
# AAGGACC: 2 - ['hsa-miR-6783-3p']
# GGACCTG: 2 - []
# GGAGAAG: 2 - []
# GAGAAGG: 2 - []
# GTGTTCA: 2 - []
# ATTTCTT: 2 - ['hsa-miR-3133']
# GAGGGAG: 2 - []
# AGGGAGG: 2 - ['hsa-miR-4667-3p']
# TCCTGTG: 2 - []
# ACCTGGT: 2 - []
# GTGGGAG: 2 - []
# GGGAGGA: 2 - []
# GGGAACT: 2 - []
# GAGATTT: 2 - []
# ATTTCCA: 2 - ['hsa-miR-12135']
# TTCCACG: 2 - []
# GGGAAAA: 2 - []
# TAGGAAA: 2 - []
# TTTAAGC: 2 - []
# GAGAAAA: 2 - []
# ATTTTGG: 2 - ['hsa-miR-548as-3p']
# TGGCTCT: 2 - []
# AGAAACA: 2 - []
# AGGAAGT: 2 - ['hsa-miR-205-5p']
# GTGAACA: 2 - []
# TTACCCA: 2 - []
# ACCCAGA: 2 - ['hsa-miR-193a-5p']
# GGGGCCC: 2 - []
# CTCACTG: 2 - []
# CCTCCTC: 2 - []
# CTCCGAA: 2 - []
# TCAAGAA: 2 - []
# GGCCTGT: 2 - []
# CGTTTTC: 2 - []
# ACGTGGA: 2 - []
# AGCATGG: 2 - ['hsa-miR-126-3p']
# CTTCTTA: 2 - []
# CTTAAGA: 2 - []
# ACATGTA: 2 - []
# AGGACAT: 2 - ['hsa-miR-486-5p']
# TGGAGAG: 2 - []
# ATCCTAA: 2 - ['hsa-miR-3159']
# CCTAAAA: 2 - []
# GTCACTG: 2 - []
# CTGTAGT: 2 - []
# AGTTTGG: 2 - []
# GTTTGGT: 2 - []
# TGACAAA: 2 - []
# AAAAAGT: 2 - ['hsa-miR-335-3p']
# ACATCCT: 2 - ['hsa-miR-8065']
# AGTGACA: 2 - ['hsa-miR-1208']
# ACTCTGT: 2 - ['hsa-miR-4524a-3p']
# TTTATCT: 2 - []
# ATGCATC: 2 - ['hsa-miR-1277-3p']
# TTTAGTT: 2 - []
# AAGGTGA: 2 - ['hsa-miR-6509-3p']
# TTCTGAG: 2 - []
# AACCAAG: 2 - []
# TTGTTTA: 2 - []
# ATTGTGA: 2 - ['hsa-miR-141-3p' 'hsa-miR-200a-3p']
# GTGACAG: 2 - []
# CCCTCCT: 2 - []
# GTATGAA: 2 - []
# GGGAACA: 2 - []
# CAGAATG: 2 - []
# AGAATGA: 2 - ['hsa-miR-550b-3p']
# TACATTG: 2 - []
# ACATTGT: 2 - ['hsa-miR-194-5p']
# GAGTCAG: 2 - []
# AGTCAGT: 2 - ['hsa-miR-4704-3p']
# TTGTTGT: 2 - []
# TATATAT: 2 - []
# TTAAGAG: 2 - []
# AAGAGGT: 2 - ['hsa-miR-515-5p' 'hsa-miR-519e-5p']
# TTAATAA: 2 - []
# CCCAGAA: 2 - []
# CTCCTCT: 2 - []
# TTTTCAT: 2 - []
# TTTCATT: 2 - []
# TTTTGCA: 2 - []
# CTCTTTA: 2 - []
# ACACTGG: 2 - ['hsa-miR-7973']
# ACTTTCC: 2 - []
# TTTGGCA: 2 - []
# AAAGTCA: 2 - []
# AGTCACA: 2 - ['hsa-miR-6733-3p']
# CACAGAA: 2 - []
# TCAAGAT: 2 - []
# ATCAGGG: 2 - ['hsa-miR-2114-5p']
# ATGTCTA: 2 - ['hsa-miR-5683']
# ATGTACA: 2 - []
# AACAGGA: 2 - []
# AGGCTCG: 2 - ['hsa-miR-615-3p']
# AAATTCT: 2 - ['hsa-miR-3658']
# AATCAGA: 2 - ['hsa-miR-4474-5p']
# TATTATG: 2 - []
# ACCTTCT: 2 - ['hsa-miR-7-5p']
# AGAGTGA: 2 - ['hsa-miR-1304-3p']
# TTGGACA: 2 - []
# AACACTG: 2 - []
# AATAAGT: 2 - ['hsa-miR-12123']
# CAACATG: 1 - []
# ATGCCTG: 1 - []
# CCAAACA: 1 - []
# TCACTAA: 1 - []
# TTGTCAG: 1 - []
# GTCAGTG: 1 - []
# ATGTACC: 1 - ['hsa-miR-4802-3p']
# TACCATG: 1 - []
# ACAAAGC: 1 - ['hsa-miR-5705']
# AACACAC: 1 - ['hsa-miR-6818-5p']
# ACATCAC: 1 - ['hsa-miR-142-3p']
# CATCACA: 1 - []
# AGACAGA: 1 - []
# GACAGAC: 1 - []
# ACAATTA: 1 - []
# AGGCAAA: 1 - []
# CAAAACG: 1 - []
# AAAACGT: 1 - ['hsa-miR-507' 'hsa-miR-450b-5p' 'hsa-miR-3680-3p']
# AAACGTC: 1 - ['hsa-miR-6516-5p']
# AACGTCG: 1 - ['hsa-miR-1301-3p' 'hsa-miR-5047']
# ACGTCGA: 1 - ['hsa-miR-4660']
# AAAGGGA: 1 - ['hsa-miR-4755-5p' 'hsa-miR-5006-3p']
# AAGGGAA: 1 - ['hsa-miR-204-5p' 'hsa-miR-211-5p']
# AGGGAAA: 1 - []
# TACATTA: 1 - []
# AGATTTA: 1 - []
# AAGACAG: 1 - []
# AGACAGT: 1 - ['hsa-miR-215-3p']
# AGTCCCA: 1 - ['hsa-miR-6823-5p']
# TCCCATC: 1 - []
# CAAAACT: 1 - []
# AAACTCC: 1 - ['hsa-miR-1304-5p']
# AACTCCT: 1 - ['hsa-miR-3915' 'hsa-miR-4689']
# ACTCCTG: 1 - ['hsa-miR-5004-5p']
# CTCCTGT: 1 - []
# AATCCGA: 1 - ['hsa-miR-12116']
# CGACCAC: 1 - []
# GACCACT: 1 - []
# AGCACCG: 1 - ['hsa-miR-1204']
# TCCACCT: 1 - []
# CACCTGG: 1 - []
# CTGTGCC: 1 - []
# AAACATA: 1 - ['hsa-miR-3149']
# TTTCCAT: 1 - []
# ATCACCA: 1 - ['hsa-miR-203b-5p' 'hsa-miR-6718-5p']
# CACCATC: 1 - []
# ACCATCT: 1 - ['hsa-miR-379-5p' 'hsa-miR-4451']
# CCATCTG: 1 - []
# CAGACGG: 1 - []
# AGACGGA: 1 - []
# ACGGATG: 1 - ['hsa-miR-24-1-5p' 'hsa-miR-24-2-5p']
# GACCTGA: 1 - []
# CCTGATC: 1 - []
# TGATCAT: 1 - []
# GATCATT: 1 - []
# AGCTGGC: 1 - ['hsa-miR-1307-5p']
# TTCTGGC: 1 - []
# CTGGGGA: 1 - []
# AAGGTGT: 1 - []
# CTGGGGG: 1 - []
# CTGTGAT: 1 - []
# GAGGGTT: 1 - []
# AGGGTTC: 1 - ['hsa-miR-6814-5p']
# GGGTTCC: 1 - []
# TTCCTGT: 1 - []
# AAGTCCA: 1 - ['hsa-miR-11399']
# CCTCCCT: 1 - []
# CTCCCTG: 1 - []
# GAAGAAG: 1 - []
# AAGAAGA: 1 - []
# AGAAGAG: 1 - ['hsa-miR-942-5p']
# GAAGAGA: 1 - []
# AGAGACT: 1 - ['hsa-miR-3921' 'hsa-miR-4653-5p']
# GAGACTC: 1 - []
# AGACTCT: 1 - ['hsa-miR-6761-5p']
# GACTCTT: 1 - []
# ACTCACA: 1 - ['hsa-miR-574-5p' 'hsa-miR-3659']
# GAAAAGA: 1 - []
# AAGAGTT: 1 - ['hsa-miR-513c-5p' 'hsa-miR-514b-5p']
# GAACTTC: 1 - []
# ATGGACC: 1 - ['hsa-miR-7851-3p']
# TGGACCT: 1 - []
# TAGTACC: 1 - []
# ACCCACT: 1 - []
# ACTGAGA: 1 - ['hsa-miR-4522']
# AGATTTC: 1 - ['hsa-miR-4744']
# GATTTCC: 1 - []
# CCACGCC: 1 - []
# CGAAGGA: 1 - []
# AGGACAG: 1 - ['hsa-miR-5699-3p' 'hsa-miR-6748-3p']
# TGCCCTT: 1 - []
# TTAAATC: 1 - []
# CTACCAA: 1 - []
# GCCGAGA: 1 - []
# AGAAAAG: 1 - ['hsa-miR-627-3p']
# CTGATTG: 1 - []
# TGTGTAT: 1 - []
# ATATTTT: 1 - ['hsa-miR-3163']
# ACGCACC: 1 - []
# CGCACCC: 1 - []
# CACCCCC: 1 - []
# ACCCCCC: 1 - ['hsa-miR-6795-5p' 'hsa-miR-6887-5p']
# AACTCCC: 1 - ['hsa-miR-6734-5p']
# ACTCCCA: 1 - ['hsa-miR-6804-5p']
# ACTGGCT: 1 - ['hsa-miR-29c-5p']
# CTCTGTC: 1 - []
# GAGTAAG: 1 - []
# AAGAAAC: 1 - ['hsa-miR-6844']
# CTCTGGA: 1 - []
# AACTTGA: 1 - ['hsa-miR-203b-3p']
# CGGTGAC: 1 - []
# GGTGACT: 1 - []
# ACTTCCG: 1 - []
# ATCAGGA: 1 - []
# CTAGAGT: 1 - []
# CACAAGT: 1 - []
# TTTTAGG: 1 - []
# AGGAGAC: 1 - []
# AGACCGA: 1 - ['hsa-miR-149-5p' 'hsa-miR-3064-5p' 'hsa-miR-4794' 'hsa-miR-6504-5p'
#  'hsa-miR-3085-3p']
# ACCGAAG: 1 - ['hsa-miR-6815-3p']
# TCCGCAG: 1 - []
# AACCTGC: 1 - ['hsa-miR-4804-5p']
# ACCTGCC: 1 - ['hsa-miR-184']
# CCTGCCT: 1 - []
# TGTGTCC: 1 - []
# CCTGGAA: 1 - []
# GGAACTG: 1 - []
# GCCGGGG: 1 - []
# CGGGGCC: 1 - []
# AGGGATG: 1 - ['hsa-miR-3162-3p']
# AACAGGG: 1 - []
# AGTGTGG: 1 - ['hsa-miR-1228-3p']
# GAATGTC: 1 - []
# CTCAGAA: 1 - []
# ATTCCAC: 1 - ['hsa-miR-18a-5p' 'hsa-miR-18b-5p']
# CACTGTC: 1 - []
# GTCAAGA: 1 - []
# GTCACCC: 1 - []
# CACCCTG: 1 - []
# TTTTCAC: 1 - []
# TTTCACG: 1 - []
# TTCACGT: 1 - []
# ATGGGAG: 1 - []
# GCCACGA: 1 - []
# ACGACCC: 1 - ['hsa-miR-4731-5p']
# GACCCTT: 1 - []
# GAGGGAA: 1 - []
# AGGGAAG: 1 - ['hsa-miR-5088-3p']
# GGAAGGA: 1 - []
# AGGCCCT: 1 - []
# CCCTTCC: 1 - []
# CCTTCCT: 1 - []
# GGACATG: 1 - []
# TGGTGAA: 1 - []
# GGAACGT: 1 - []
# AACGTGA: 1 - ['hsa-miR-4325' 'hsa-miR-7703']
# ACGTGAG: 1 - []
# GTGAGGA: 1 - []
# AGGAGAG: 1 - []
# TTTTGGC: 1 - []
# GGCACGT: 1 - []
# TGTGTGG: 1 - []
# CCCACCT: 1 - []
# CACCTGT: 1 - []
# TGAGTTT: 1 - []
# GAGTTTA: 1 - []
# TTTAAAG: 1 - []
# TAAATGA: 1 - []
# AGAGGGT: 1 - ['hsa-miR-150-5p']
# GGTCACA: 1 - []
# AAATCCT: 1 - ['hsa-miR-651-5p']
# AATCCTA: 1 - []
# AGTGAGG: 1 - ['hsa-miR-483-3p']
# TGTCATG: 1 - []
# ATTGACC: 1 - ['hsa-miR-582-3p']
# GACCCCT: 1 - []
# ACCCCTG: 1 - ['hsa-miR-3191-3p']
# TCTTGTC: 1 - []
# AACCTGA: 1 - ['hsa-miR-5009-5p']
# ACCTGAC: 1 - ['hsa-miR-1288-3p']
# AAAAGTT: 1 - ['hsa-miR-1305']
# AAAGTTC: 1 - ['hsa-miR-498-5p']
# GTGTGGA: 1 - []
# ATGGGGG: 1 - []
# ATTAAAA: 1 - ['hsa-miR-590-3p']
# CTATAAA: 1 - []
# AGAAGTG: 1 - ['hsa-miR-6754-3p']
# AAGTGAC: 1 - ['hsa-miR-653-3p']
# TGACATC: 1 - []
# CTTCCAG: 1 - []
# TTCCAGT: 1 - []
# GTTTAGA: 1 - []
# TTATATA: 1 - []
# ATATACC: 1 - ['hsa-miR-8076']
# ATACCAT: 1 - ['hsa-miR-5579-5p']
# ATTTATC: 1 - ['hsa-miR-3121-3p']
# AACTTTG: 1 - []
# ATATTTC: 1 - []
# ATTTCGA: 1 - []
# ATCTCAG: 1 - ['hsa-miR-5007-5p']
# GTTTTTT: 1 - []
# AATTGTA: 1 - []
# ATTGTAT: 1 - ['hsa-miR-4803']
# CCTATAC: 1 - []
# CTATACA: 1 - []
# ATACACT: 1 - ['hsa-miR-4501']
# ACACTAT: 1 - ['hsa-miR-3689a-5p' 'hsa-miR-3689b-5p' 'hsa-miR-3689e' 'hsa-miR-3689f']
# ATCGTTT: 1 - ['hsa-miR-548p']
# TCGTTTT: 1 - []
# TTGAGAT: 1 - []
# TATCTCT: 1 - []
# TCTCTTG: 1 - []
# CTCTTGA: 1 - []
# AGGTGAG: 1 - ['hsa-miR-6777-3p']
# GGTGAGA: 1 - []
# AGATAAG: 1 - ['hsa-miR-6731-3p']
# CTACCTA: 1 - []
# TACCTAA: 1 - []
# CCTAAGA: 1 - []
# GATGTCA: 1 - []
# CACGTCA: 1 - []
# ATTGTTT: 1 - ['hsa-miR-5688']
# TTGTGAC: 1 - []
# TCCCTTT: 1 - []
# CTTTGAC: 1 - []
# TTTCTTG: 1 - []
# TTCTTGA: 1 - []
# CCTCGTC: 1 - []
# TCGTCCC: 1 - []
# GTCCCTG: 1 - []
# TCATGGT: 1 - []
# ACCCATG: 1 - []
# AAATCTA: 1 - ['hsa-miR-4760-5p']
# TTAGAGA: 1 - []
# AGAGAGT: 1 - ['hsa-miR-12125']
# TACGTGG: 1 - []
# TTCAACA: 1 - []
# AACACAG: 1 - ['hsa-miR-592']
# ACAGACC: 1 - []
# AGACCCA: 1 - ['hsa-miR-6776-5p']
# GACCCAC: 1 - []
# ACCCACC: 1 - ['hsa-miR-1293' 'hsa-miR-6745']
# CCCACCC: 1 - []
# CCACCCA: 1 - []
# AGCCCTC: 1 - []
# CCTCCTG: 1 - []
# CCTCCTT: 1 - []
# TCCTTCC: 1 - []
# TTCCGCG: 1 - []
# CCGCGGG: 1 - []
# CTCATGG: 1 - []
# TCAGGGT: 1 - []
# TCCTGAA: 1 - []
# ATGCAGT: 1 - ['hsa-miR-598-3p']
# AGTGGTG: 1 - []
# ACGCTCC: 1 - []
# CGCTCCA: 1 - []
# CCACCAA: 1 - []
# CACCAAG: 1 - []
# ACCAAGA: 1 - ['hsa-miR-182-3p' 'hsa-miR-597-3p']
# AGGAAAC: 1 - ['hsa-miR-3121-5p']
# AACCTGT: 1 - ['hsa-miR-4520-3p']
# AGACCTC: 1 - []
# ACCTCCC: 1 - []
# CTCCCCG: 1 - []
# CCCCGGC: 1 - []
# CGGCGGG: 1 - []
# GGGCCTC: 1 - []
# CCTCAGG: 1 - []
# AGGGAAC: 1 - ['hsa-miR-6780b-3p']
# AGACCTT: 1 - []
# ACCTTTG: 1 - ['hsa-miR-147b-5p']
# AATATTA: 1 - ['hsa-miR-374a-5p']
# ATATTAT: 1 - []
# TATTTTA: 1 - []
# ATATGGA: 1 - ['hsa-miR-875-5p']
# ATCCAAT: 1 - ['hsa-miR-154-5p']
# CAATCCT: 1 - []
# ATCCTGT: 1 - ['hsa-miR-1197']
# ATTTTAA: 1 - ['hsa-miR-4282']
# ATGGAGT: 1 - []
# TGCAGTA: 1 - []
# ACGTGGT: 1 - ['hsa-miR-767-5p']
# CGTGGTA: 1 - []
# ATCCTCC: 1 - ['hsa-miR-4779']
# ATGAAGA: 1 - []
# CGTGGAC: 1 - []
# ACGTTTT: 1 - ['hsa-miR-548f-5p' 'hsa-miR-548g-5p' 'hsa-miR-548x-5p' 'hsa-miR-548aj-5p']
# ACGGGAT: 1 - ['hsa-miR-18b-3p']
# CGGGATT: 1 - []
# ATATATA: 1 - ['hsa-miR-5011-5p']
# GAGGTCA: 1 - []
# AGGTCAC: 1 - ['hsa-miR-1825']
# GGTCACG: 1 - []
# TCACGGG: 1 - []
# TTTTGCT: 1 - []
# ATAACAG: 1 - []
# TGTGCCC: 1 - []
# CTCTTGG: 1 - []
# TGGCCCC: 1 - []
# AACATGT: 1 - ['hsa-miR-493-5p']
# ACATGTT: 1 - []
# CTCAACT: 1 - []
# ACTAGTC: 1 - ['hsa-miR-4772-5p']
# AGTCATT: 1 - ['hsa-miR-545-5p']
# GTCATTT: 1 - []
# TTTCTCC: 1 - []
# CCTCTTC: 1 - []
# CTCTTCT: 1 - []
# TTTTTCA: 1 - []
# ACAGAGA: 1 - ['hsa-miR-593-3p' 'hsa-miR-6895-3p']
# ATCCCTA: 1 - ['hsa-miR-6757-5p']
# AAGAGGG: 1 - ['hsa-miR-4713-5p']
# TCACATC: 1 - []
# ATCTGCA: 1 - ['hsa-miR-6863']
# ATGAAAA: 1 - ['hsa-miR-5003-3p']
# AAAAAAC: 1 - ['hsa-miR-9983-3p']
# GTCCTCT: 1 - []
# ACTCCTC: 1 - ['hsa-miR-3150b-3p' 'hsa-miR-4784']
# TCTTTAC: 1 - []
# TTACACT: 1 - []
# TACACTG: 1 - []
# GCCAGGG: 1 - []
# TTTCCAA: 1 - []
# AAATTGG: 1 - []
# GGACAAG: 1 - []
# GGGCTCT: 1 - []
# AAAGGAG: 1 - ['hsa-miR-670-3p' 'hsa-miR-3059-5p']
# AAGGAGA: 1 - []
# AGGAGAA: 1 - ['hsa-miR-877-3p']
# AGAAGAA: 1 - ['hsa-miR-4778-3p']
# AAGAACA: 1 - []
# AACATCT: 1 - []
# GAACCTC: 1 - []
# AACCTCC: 1 - ['hsa-miR-4443' 'hsa-miR-6515-5p']
# ACCTCCT: 1 - ['hsa-miR-765']
# CCCTCCC: 1 - []
# TCCCAGT: 1 - []
# AGTCCCT: 1 - ['hsa-miR-4270']
# GTCCCTC: 1 - []
# CCCTCGC: 1 - []
# ACTCCGC: 1 - []
# CAAGAGA: 1 - []
# AAGAGAG: 1 - ['hsa-miR-6873-3p']
# ACAGGGT: 1 - []
# GGTCTAT: 1 - []
# GGTCGTC: 1 - []
# GTCGTCT: 1 - []
# CGTCTCC: 1 - []
# CCGAAGA: 1 - []
# ACTCTGG: 1 - ['hsa-miR-769-5p' 'hsa-miR-4786-5p']
# TAAAGTC: 1 - []
# GTCACAG: 1 - []
# AAGGAAG: 1 - ['hsa-miR-6868-3p']
# ACCTCAA: 1 - ['hsa-miR-4653-3p']
# CCTCAAT: 1 - []
# CTCAATT: 1 - []
# AAACAAG: 1 - ['hsa-miR-375-3p']
# AACAAGA: 1 - ['hsa-miR-4677-5p' 'hsa-miR-7156-5p']
# TCTCTCC: 1 - []
# CACTTAC: 1 - []
# ACTTACC: 1 - ['hsa-miR-4790-3p']
# ACCTCTC: 1 - ['hsa-miR-185-5p' 'hsa-miR-4306' 'hsa-miR-4644']
# CCTCTCT: 1 - []
# TGTGTTC: 1 - []
# TGTTCAG: 1 - []
# CAGATGT: 1 - []
# GCCTTCC: 1 - []
# TTCCATT: 1 - []
# ATATGTG: 1 - []
# TGTGATC: 1 - []
# ATCATCT: 1 - ['hsa-miR-411-5p']
# CATCTAA: 1 - []
# CAGTGGG: 1 - []
# AGTGGGA: 1 - ['hsa-miR-3620-3p']
# ATTAGGA: 1 - ['hsa-miR-500a-5p']
# TTAGGAA: 1 - []
# GAGAGGA: 1 - []
# AGAGGAG: 1 - []
# GTTATAA: 1 - []
# TATAATA: 1 - []
# ATAATAA: 1 - []
# TAATAAT: 1 - []
# AAGATTA: 1 - []
# GATTAAA: 1 - []
# GTAAATA: 1 - []
# AATCAGG: 1 - ['hsa-miR-4540']
# TCCCAAC: 1 - []
# CCCAACA: 1 - []
# ACACATG: 1 - ['hsa-miR-3177-5p']
# CACATGT: 1 - []
# ACATGTC: 1 - []
# TTTCACC: 1 - []
# TTCACCT: 1 - []
# TCACCTC: 1 - []
# CACCTCC: 1 - []
# ATCTATT: 1 - ['hsa-miR-577']
# TTGAGTG: 1 - []
# TGAGTGA: 1 - []
# AATAGTC: 1 - ['hsa-miR-361-5p']
# ATAGTCT: 1 - []
# GTCTCTA: 1 - []
# TCTATTT: 1 - []
# ACTTATC: 1 - []
# AGTTTAT: 1 - []
# AACTTAA: 1 - ['hsa-miR-4452']
# CCAACTG: 1 - []
# TTTTTAG: 1 - []
# AGACTTT: 1 - ['hsa-miR-4766-5p']
# GACTTTC: 1 - []
# TTTCTTA: 1 - []
# TTCTTAT: 1 - []
# ATCACTT: 1 - []
# AGTTAGT: 1 - ['hsa-miR-4705']
# TACACCT: 1 - []
# ACACCTA: 1 - []
# CACCTAC: 1 - []
# ACCTACT: 1 - ['hsa-miR-6744-5p']
# CCTACTC: 1 - []
# ATCAGAG: 1 - []
# AGAGAAA: 1 - []
# AAGCCAT: 1 - ['hsa-miR-4798-5p']
# CTAAGGA: 1 - []
# TGGTGTC: 1 - []
# CCAGACA: 1 - []
# ACACACT: 1 - []
# AGATCTT: 1 - ['hsa-miR-6508-5p']
# TTTCAGG: 1 - []
# ATGGGAC: 1 - ['hsa-miR-10a-5p' 'hsa-miR-10b-5p']
# TGGGACA: 1 - []
# ACATTTG: 1 - ['hsa-miR-30a-5p' 'hsa-miR-30c-5p' 'hsa-miR-30d-5p' 'hsa-miR-30b-5p'
#  'hsa-miR-30e-5p']
# CATTTGT: 1 - []
# AGGAAGA: 1 - ['hsa-miR-1237-3p']
# GGAAGAA: 1 - []
# GATCAGG: 1 - []
# TTCAGAA: 1 - []
# GACCTGT: 1 - []
# GTCGATG: 1 - []
# GCCTCTG: 1 - []
# CCTCTGC: 1 - []
# CGAAGAA: 1 - []
# TGTGTGA: 1 - []
# GTGACAA: 1 - []
# ATTTTGA: 1 - ['hsa-miR-548ar-3p' 'hsa-miR-5582-3p']
# TTTTGAA: 1 - []
# TTGTGGT: 1 - []
# ACGACCT: 1 - ['hsa-miR-1287-5p']
# CAGAGAC: 1 - []
# AGACATC: 1 - ['hsa-miR-3137']
# GACATCA: 1 - []
# GCATGGC: 1 - []
# AGTGCAG: 1 - ['hsa-miR-11401']
# CCGTTTG: 1 - []
# GATATGT: 1 - []
# ATATGTC: 1 - []
# ATGGGTA: 1 - ['hsa-miR-660-5p']
# ATTTAAA: 1 - ['hsa-miR-513a-3p' 'hsa-miR-513c-3p']
# AGTTTTA: 1 - ['hsa-miR-4698' 'hsa-miR-8063']
# ACTAACA: 1 - ['hsa-miR-219a-5p' 'hsa-miR-508-3p' 'hsa-miR-4782-3p' 'hsa-miR-6766-3p']
# CTAACAG: 1 - []
# ACAGGAT: 1 - []
# AGGATAT: 1 - []
# TAATGAC: 1 - []
# AACCTTC: 1 - ['hsa-miR-6079']
# CCTTCTG: 1 - []
# AGGGACA: 1 - ['hsa-miR-339-5p']
# ATTATGT: 1 - []
# ATACAGA: 1 - ['hsa-miR-654-3p']
# ACAGAAA: 1 - ['hsa-miR-6830-3p']
# GAGAGTG: 1 - []
# TCCTTTA: 1 - []
# TAGTCTT: 1 - []
# TGTTCCA: 1 - []
# ATCATGA: 1 - ['hsa-miR-1278']
# TCTCACT: 1 - []
# ACTGGAT: 1 - []
# TGAATGG: 1 - []
# TGTACCG: 1 - []
# ACCGGTT: 1 - ['hsa-miR-3926']
# CGGTTCA: 1 - []
# GTTCATC: 1 - []
# TCATCTG: 1 - []
# ATCTGGA: 1 - []
# ACTTCAA: 1 - ['hsa-miR-4670-3p']
# AGCAAAC: 1 - ['hsa-miR-1282']
# ATACCAA: 1 - []
# TACCAAG: 1 - []
# TGAGCAC: 1 - []
# AGCACAG: 1 - ['hsa-miR-187-3p' 'hsa-miR-6774-3p']
# GCACAGA: 1 - []
# ACAGAAG: 1 - ['hsa-miR-6740-3p']
# CAGAAGA: 1 - []
# GTGGAGG: 1 - []
# AAAATTC: 1 - ['hsa-miR-7856-5p']
# AATTCTG: 1 - ['hsa-miR-499a-5p']
# CTGAGAC: 1 - []
# TGAGACT: 1 - []
# AGACTGT: 1 - ['hsa-miR-6719-3p']
# GACTGTA: 1 - []
# TGTAGTG: 1 - []
# AATCCAT: 1 - []
# CACCTAA: 1 - []
# ACCTAAA: 1 - ['hsa-miR-876-5p' 'hsa-miR-1290']
# ACCTTTT: 1 - ['hsa-miR-3148']
# ATTTCAT: 1 - ['hsa-miR-559']
# TCCCTCC: 1 - []
# GAATTTG: 1 - []
# GAGTGAC: 1 - []
# GACAGTG: 1 - []
# ACAGTGG: 1 - ['hsa-miR-6879-3p']
# TTTTGGG: 1 - []
# TTTGGGG: 1 - []
# TTTTGGT: 1 - []
# TTTGGTG: 1 - []
# TTGGTGG: 1 - []
# TATTATA: 1 - []
# TTATACC: 1 - []
# TATACCT: 1 - []
# ATACCTT: 1 - ['hsa-miR-3688-3p']
# ACCAAGG: 1 - []
# GTTTTGA: 1 - []
# ACTGGGG: 1 - ['hsa-miR-6846-3p' 'hsa-miR-6859-3p']
# GTTATTT: 1 - []
# ATTTTTG: 1 - ['hsa-miR-548x-3p' 'hsa-miR-548aj-3p']
# AAGTGTT: 1 - ['hsa-miR-513b-5p']
# AGTGTTT: 1 - ['hsa-miR-4719']
# TTTCATA: 1 - []
# TTTACCT: 1 - []
# ACCTTCC: 1 - ['hsa-miR-3202' 'hsa-miR-4533']
# TGGCTGA: 1 - []
# ATTCTGC: 1 - []
# ACACTGT: 1 - ['hsa-miR-542-3p' 'hsa-miR-4504']
# GTACACA: 1 - []
# TACACAT: 1 - []
# CACATAA: 1 - []
# AAGGATA: 1 - ['hsa-miR-202-5p']
# AGGATAC: 1 - []
# ACTTTAC: 1 - []
# AAGTAAG: 1 - ['hsa-miR-1298-5p']
# TAAGTCT: 1 - []
# GTCTCCA: 1 - []
# ATAATGG: 1 - []
# ACTTTGT: 1 - ['hsa-miR-494-3p']
# TTGTTTG: 1 - []
# GTGTTGT: 1 - []
# AACTTTC: 1 - ['hsa-miR-488-3p']
# TTCCTTG: 1 - []
# GTCTGTC: 1 - []
# GTCTAGT: 1 - []
# ACAGTGT: 1 - ['hsa-miR-12122']

# %%
# top matching 7mer-m8's

seeds = find_seed_in_kmers(generate_kmers(sequence, 7), seed_kmers)

for kmer, count in seeds.items():
    if count != 0:
        possible_sequences = mirna_df.loc[(mirna_df['7mer-m8'] == kmer)]["name"].values
        print(f"{kmer}: {count} - {possible_sequences}")
# Out:
# ACACACA: 8 - []
# CACACAC: 6 - ['hsa-miR-6867-5p']
# ACAGAAT: 5 - []
# TGTTGTT: 4 - ['hsa-miR-3529-3p']
# GAAGTGA: 4 - ['hsa-miR-6837-3p']
# GGGCCCT: 4 - ['hsa-miR-1247-3p']
# CATTGTC: 3 - ['hsa-miR-194-5p']
# ATTGTCA: 3 - []
# GGGGAAG: 3 - ['hsa-miR-3127-3p' 'hsa-miR-6756-3p']
# AACAGAG: 3 - []
# AGAGGGA: 3 - ['hsa-miR-6867-3p']
# AAGGACA: 3 - ['hsa-miR-7152-5p']
# AGAACCT: 3 - []
# CCCTCCA: 3 - ['hsa-miR-6799-5p']
# ACTGTAG: 3 - ['hsa-miR-489-3p']
# AAAGAAG: 3 - []
# AAACCTG: 3 - ['hsa-miR-7850-5p']
# TGCATCT: 3 - ['hsa-miR-1277-3p']
# TTGTATT: 3 - ['hsa-miR-4803']
# ATTCTGA: 3 - ['hsa-miR-499a-5p']
# GACCTTT: 3 - ['hsa-miR-875-3p']
# TCAGGGA: 3 - ['hsa-miR-2114-5p']
# CTTTTGT: 3 - ['hsa-miR-570-3p']
# AGTAAAT: 3 - ['hsa-miR-5696']
# ATGAATG: 3 - []
# GATCTTT: 3 - ['hsa-miR-6508-5p' 'hsa-miR-8067']
# TTTATTA: 3 - ['hsa-miR-5692a']
# ATCAAGA: 3 - []
# TTTTAAA: 3 - ['hsa-miR-4282']
# CCCCAAA: 2 - ['hsa-miR-193b-5p']
# CAAACAA: 2 - ['hsa-miR-8068']
# AGTGATG: 2 - []
# AATAACA: 2 - []
# ACATTAT: 2 - ['hsa-miR-2054']
# TAAGACA: 2 - ['hsa-miR-4778-5p']
# CTCCACC: 2 - ['hsa-miR-6134']
# CCACCTG: 2 - ['hsa-miR-8071']
# ACCTGGA: 2 - ['hsa-miR-4535']
# CTTTCCA: 2 - ['hsa-miR-6730-5p']
# CTGAAGA: 2 - ['hsa-miR-6505-3p']
# AAAGGAC: 2 - []
# AAGGACC: 2 - []
# GGACCTG: 2 - ['hsa-miR-3690']
# GGAGAAG: 2 - ['hsa-miR-877-3p']
# GAGAAGG: 2 - ['hsa-miR-1236-3p']
# GTGTTCA: 2 - ['hsa-miR-125b-2-3p']
# ATTTCTT: 2 - []
# GAGGGAG: 2 - ['hsa-miR-4469']
# AGGGAGG: 2 - []
# TCCTGTG: 2 - ['hsa-miR-1197']
# ACCTGGT: 2 - ['hsa-miR-4776-5p']
# GTGGGAG: 2 - ['hsa-miR-6865-3p']
# GGGAGGA: 2 - ['hsa-miR-4667-3p']
# GGGAACT: 2 - ['hsa-miR-4780']
# GAGATTT: 2 - ['hsa-miR-520f-5p']
# ATTTCCA: 2 - []
# TTCCACG: 2 - ['hsa-miR-18a-5p' 'hsa-miR-18b-5p' 'hsa-miR-4735-3p']
# GGGAAAA: 2 - ['hsa-miR-6832-3p']
# TAGGAAA: 2 - ['hsa-miR-501-5p']
# TTTAAGC: 2 - ['hsa-miR-10a-3p']
# GAGAAAA: 2 - ['hsa-miR-130a-5p']
# ATTTTGG: 2 - []
# TGGCTCT: 2 - ['hsa-miR-4523']
# AGAAACA: 2 - ['hsa-miR-6844']
# AGGAAGT: 2 - []
# GTGAACA: 2 - ['hsa-miR-6500-3p']
# TTACCCA: 2 - ['hsa-miR-4506']
# ACCCAGA: 2 - []
# GGGGCCC: 2 - ['hsa-miR-5587-3p']
# CTCACTG: 2 - ['hsa-miR-1236-5p']
# CCTCCTC: 2 - ['hsa-miR-765' 'hsa-miR-11181-3p']
# CTCCGAA: 2 - ['hsa-miR-3188']
# TCAAGAA: 2 - ['hsa-miR-5584-3p']
# GGCCTGT: 2 - ['hsa-miR-4442']
# CGTTTTC: 2 - ['hsa-miR-548f-5p' 'hsa-miR-548g-5p' 'hsa-miR-548x-5p' 'hsa-miR-548aj-5p']
# ACGTGGA: 2 - ['hsa-miR-500a-3p']
# AGCATGG: 2 - []
# CTTCTTA: 2 - ['hsa-miR-10522-5p']
# CTTAAGA: 2 - ['hsa-miR-10393-5p']
# ACATGTA: 2 - ['hsa-miR-493-5p']
# AGGACAT: 2 - []
# TGGAGAG: 2 - ['hsa-miR-6800-3p']
# ATCCTAA: 2 - []
# CCTAAAA: 2 - ['hsa-miR-1290']
# GTCACTG: 2 - ['hsa-miR-5190']
# CTGTAGT: 2 - ['hsa-miR-3913-3p']
# AGTTTGG: 2 - ['hsa-miR-6715b-3p']
# GTTTGGT: 2 - ['hsa-miR-6715a-3p']
# TGACAAA: 2 - ['hsa-miR-452-5p' 'hsa-miR-4676-3p' 'hsa-miR-892c-3p']
# AAAAAGT: 2 - []
# ACATCCT: 2 - []
# AGTGACA: 2 - []
# ACTCTGT: 2 - []
# TTTATCT: 2 - ['hsa-miR-3121-3p']
# ATGCATC: 2 - []
# TTTAGTT: 2 - ['hsa-miR-551b-5p']
# AAGGTGA: 2 - []
# TTCTGAG: 2 - ['hsa-miR-4432']
# AACCAAG: 2 - ['hsa-miR-659-3p']
# TTGTTTA: 2 - ['hsa-miR-7-1-3p' 'hsa-miR-7-2-3p']
# ATTGTGA: 2 - []
# GTGACAG: 2 - ['hsa-miR-6760-3p']
# CCCTCCT: 2 - ['hsa-miR-7106-5p']
# GTATGAA: 2 - ['hsa-miR-1-5p']
# GGGAACA: 2 - ['hsa-miR-6780b-3p']
# CAGAATG: 2 - ['hsa-miR-200c-5p' 'hsa-miR-550a-3p']
# AGAATGA: 2 - []
# TACATTG: 2 - ['hsa-miR-379-3p' 'hsa-miR-411-3p']
# ACATTGT: 2 - []
# GAGTCAG: 2 - ['hsa-miR-4264']
# AGTCAGT: 2 - []
# TTGTTGT: 2 - ['hsa-miR-196a-1-3p']
# TATATAT: 2 - ['hsa-miR-5011-5p']
# TTAAGAG: 2 - ['hsa-miR-5571-5p']
# AAGAGGT: 2 - []
# TTAATAA: 2 - ['hsa-miR-944']
# CCCAGAA: 2 - ['hsa-miR-193a-5p']
# CTCCTCT: 2 - ['hsa-miR-3150b-3p' 'hsa-miR-4784']
# TTTTCAT: 2 - ['hsa-miR-548n']
# TTTCATT: 2 - ['hsa-miR-559' 'hsa-miR-548b-5p' 'hsa-miR-548a-5p' 'hsa-miR-548c-5p'
#  'hsa-miR-548d-5p' 'hsa-miR-548j-5p' 'hsa-miR-548h-5p' 'hsa-miR-548i'
#  'hsa-miR-548w' 'hsa-miR-548y' 'hsa-miR-548o-5p' 'hsa-miR-548ab'
#  'hsa-miR-548ad-5p' 'hsa-miR-548ae-5p' 'hsa-miR-548ak' 'hsa-miR-548am-5p'
#  'hsa-miR-548ap-5p' 'hsa-miR-548aq-5p' 'hsa-miR-548ar-5p'
#  'hsa-miR-548as-5p' 'hsa-miR-548au-5p' 'hsa-miR-548ay-5p'
#  'hsa-miR-548bb-5p']
# TTTTGCA: 2 - ['hsa-miR-424-3p']
# CTCTTTA: 2 - ['hsa-miR-539-5p']
# ACACTGG: 2 - ['hsa-miR-6808-3p']
# ACTTTCC: 2 - ['hsa-miR-488-3p']
# TTTGGCA: 2 - ['hsa-miR-1537-3p']
# AAAGTCA: 2 - ['hsa-miR-30a-3p' 'hsa-miR-30d-3p' 'hsa-miR-30e-3p']
# AGTCACA: 2 - []
# CACAGAA: 2 - ['hsa-miR-4711-3p']
# TCAAGAT: 2 - ['hsa-miR-3168']
# ATCAGGG: 2 - []
# ATGTCTA: 2 - []
# ATGTACA: 2 - ['hsa-miR-4666a-5p']
# AACAGGA: 2 - ['hsa-miR-2355-3p']
# AGGCTCG: 2 - []
# AAATTCT: 2 - []
# AATCAGA: 2 - []
# TATTATG: 2 - ['hsa-miR-369-3p']
# ACCTTCT: 2 - []
# AGAGTGA: 2 - []
# TTGGACA: 2 - ['hsa-miR-649']
# AACACTG: 2 - ['hsa-miR-758-3p']
# AATAAGT: 2 - []
# CAACATG: 1 - ['hsa-miR-3613-5p']
# ATGCCTG: 1 - ['hsa-miR-4788']
# CCAAACA: 1 - ['hsa-miR-5087']
# TCACTAA: 1 - ['hsa-miR-8062']
# TTGTCAG: 1 - ['hsa-miR-212-3p' 'hsa-miR-132-3p']
# GTCAGTG: 1 - ['hsa-miR-4704-3p']
# ATGTACC: 1 - []
# TACCATG: 1 - ['hsa-miR-5579-5p']
# ACAAAGC: 1 - []
# AACACAC: 1 - []
# ACATCAC: 1 - []
# CATCACA: 1 - ['hsa-miR-142-3p']
# AGACAGA: 1 - ['hsa-miR-6888-3p']
# GACAGAC: 1 - ['hsa-miR-3120-5p']
# ACAATTA: 1 - ['hsa-miR-2053']
# AGGCAAA: 1 - ['hsa-miR-1468-5p']
# CAAAACG: 1 - ['hsa-miR-19a-5p' 'hsa-miR-19b-1-5p' 'hsa-miR-19b-2-5p']
# AAAACGT: 1 - []
# AAACGTC: 1 - []
# AACGTCG: 1 - []
# ACGTCGA: 1 - ['hsa-miR-1301-3p' 'hsa-miR-5047']
# AAAGGGA: 1 - ['hsa-miR-4446-5p']
# AAGGGAA: 1 - ['hsa-miR-4755-5p' 'hsa-miR-5006-3p']
# AGGGAAA: 1 - ['hsa-miR-204-5p' 'hsa-miR-211-5p']
# TACATTA: 1 - ['hsa-miR-380-3p']
# AGATTTA: 1 - ['hsa-miR-4799-5p']
# AAGACAG: 1 - ['hsa-miR-4743-3p']
# AGACAGT: 1 - []
# AGTCCCA: 1 - []
# TCCCATC: 1 - ['hsa-miR-6755-5p']
# CAAAACT: 1 - ['hsa-miR-2052']
# AAACTCC: 1 - []
# AACTCCT: 1 - []
# ACTCCTG: 1 - ['hsa-miR-1224-5p']
# CTCCTGT: 1 - ['hsa-miR-5004-5p']
# AATCCGA: 1 - []
# CGACCAC: 1 - ['hsa-miR-138-5p']
# GACCACT: 1 - ['hsa-miR-4299']
# AGCACCG: 1 - []
# TCCACCT: 1 - ['hsa-miR-12114']
# CACCTGG: 1 - ['hsa-miR-4800-5p']
# CTGTGCC: 1 - ['hsa-miR-4462']
# AAACATA: 1 - []
# TTTCCAT: 1 - ['hsa-miR-548m']
# ATCACCA: 1 - ['hsa-miR-4460']
# CACCATC: 1 - ['hsa-miR-4536-5p']
# ACCATCT: 1 - []
# CCATCTG: 1 - ['hsa-miR-379-5p' 'hsa-miR-3529-5p']
# CAGACGG: 1 - ['hsa-miR-346']
# AGACGGA: 1 - ['hsa-miR-5001-3p']
# ACGGATG: 1 - []
# GACCTGA: 1 - ['hsa-miR-378a-3p' 'hsa-miR-422a' 'hsa-miR-378d' 'hsa-miR-378b'
#  'hsa-miR-378c' 'hsa-miR-378e' 'hsa-miR-378f' 'hsa-miR-378h'
#  'hsa-miR-378i']
# CCTGATC: 1 - ['hsa-miR-6503-3p']
# TGATCAT: 1 - ['hsa-miR-3923']
# GATCATT: 1 - ['hsa-miR-628-3p']
# AGCTGGC: 1 - []
# TTCTGGC: 1 - ['hsa-miR-548ao-3p']
# CTGGGGA: 1 - ['hsa-miR-6846-3p']
# AAGGTGT: 1 - ['hsa-miR-3692-3p']
# CTGGGGG: 1 - ['hsa-miR-6859-3p']
# CTGTGAT: 1 - ['hsa-miR-3117-5p']
# GAGGGTT: 1 - ['hsa-miR-150-5p']
# AGGGTTC: 1 - []
# GGGTTCC: 1 - ['hsa-miR-6814-5p']
# TTCCTGT: 1 - ['hsa-miR-8080']
# AAGTCCA: 1 - []
# CCTCCCT: 1 - ['hsa-miR-1249-5p' 'hsa-miR-6797-5p']
# CTCCCTG: 1 - ['hsa-miR-3126-5p' 'hsa-miR-6875-5p']
# GAAGAAG: 1 - ['hsa-miR-4778-3p']
# AAGAAGA: 1 - ['hsa-miR-4659a-3p' 'hsa-miR-4659b-3p']
# AGAAGAG: 1 - []
# GAAGAGA: 1 - ['hsa-miR-942-5p']
# AGAGACT: 1 - []
# GAGACTC: 1 - ['hsa-miR-3921' 'hsa-miR-4653-5p']
# AGACTCT: 1 - []
# GACTCTT: 1 - ['hsa-miR-4251']
# ACTCACA: 1 - ['hsa-miR-4658' 'hsa-miR-6790-5p']
# GAAAAGA: 1 - ['hsa-miR-627-3p']
# AAGAGTT: 1 - []
# GAACTTC: 1 - ['hsa-miR-4635']
# ATGGACC: 1 - []
# TGGACCT: 1 - ['hsa-miR-619-3p']
# TAGTACC: 1 - ['hsa-miR-2681-3p']
# ACCCACT: 1 - ['hsa-miR-1262' 'hsa-miR-4701-3p' 'hsa-miR-6736-5p']
# ACTGAGA: 1 - []
# AGATTTC: 1 - []
# GATTTCC: 1 - ['hsa-miR-4509']
# CCACGCC: 1 - ['hsa-miR-675-5p' 'hsa-miR-4466']
# CGAAGGA: 1 - ['hsa-miR-516b-3p' 'hsa-miR-516a-3p' 'hsa-miR-7162-5p']
# AGGACAG: 1 - []
# TGCCCTT: 1 - ['hsa-miR-4681']
# TTAAATC: 1 - ['hsa-miR-32-3p']
# CTACCAA: 1 - ['hsa-miR-8069']
# GCCGAGA: 1 - ['hsa-miR-6741-3p']
# AGAAAAG: 1 - []
# CTGATTG: 1 - ['hsa-miR-6831-3p']
# TGTGTAT: 1 - ['hsa-miR-4789-3p']
# ATATTTT: 1 - []
# ACGCACC: 1 - ['hsa-miR-6821-5p']
# CGCACCC: 1 - ['hsa-miR-6853-5p']
# CACCCCC: 1 - ['hsa-miR-4447' 'hsa-miR-4472']
# ACCCCCC: 1 - ['hsa-miR-7109-5p']
# AACTCCC: 1 - []
# ACTCCCA: 1 - []
# ACTGGCT: 1 - []
# CTCTGTC: 1 - ['hsa-miR-4524a-3p']
# GAGTAAG: 1 - ['hsa-miR-6758-3p']
# AAGAAAC: 1 - []
# CTCTGGA: 1 - ['hsa-miR-769-5p']
# AACTTGA: 1 - []
# CGGTGAC: 1 - ['hsa-miR-4252']
# GGTGACT: 1 - ['hsa-miR-181a-2-3p']
# ACTTCCG: 1 - ['hsa-miR-6126']
# ATCAGGA: 1 - ['hsa-miR-4540']
# CTAGAGT: 1 - ['hsa-miR-4695-3p']
# CACAAGT: 1 - ['hsa-miR-124-5p']
# TTTTAGG: 1 - ['hsa-miR-4668-3p']
# AGGAGAC: 1 - ['hsa-miR-6780a-3p']
# AGACCGA: 1 - []
# ACCGAAG: 1 - []
# TCCGCAG: 1 - ['hsa-miR-3186-5p']
# AACCTGC: 1 - []
# ACCTGCC: 1 - ['hsa-miR-4804-5p']
# CCTGCCT: 1 - ['hsa-miR-184']
# TGTGTCC: 1 - ['hsa-miR-6768-5p']
# CCTGGAA: 1 - ['hsa-miR-659-5p']
# GGAACTG: 1 - ['hsa-miR-10397-5p']
# GCCGGGG: 1 - ['hsa-miR-10392-3p']
# CGGGGCC: 1 - ['hsa-miR-10396a-3p' 'hsa-miR-10396b-3p']
# AGGGATG: 1 - []
# AACAGGG: 1 - ['hsa-miR-4646-3p']
# AGTGTGG: 1 - []
# GAATGTC: 1 - ['hsa-miR-600']
# CTCAGAA: 1 - ['hsa-miR-924']
# ATTCCAC: 1 - []
# CACTGTC: 1 - ['hsa-miR-542-3p']
# GTCAAGA: 1 - ['hsa-miR-4277']
# GTCACCC: 1 - ['hsa-miR-194-3p']
# CACCCTG: 1 - ['hsa-miR-4648']
# TTTTCAC: 1 - ['hsa-miR-548t-5p' 'hsa-miR-548az-5p']
# TTTCACG: 1 - ['hsa-miR-17-5p' 'hsa-miR-20a-5p' 'hsa-miR-93-5p' 'hsa-miR-106a-5p'
#  'hsa-miR-106b-5p' 'hsa-miR-20b-5p' 'hsa-miR-526b-3p' 'hsa-miR-519d-3p']
# TTCACGT: 1 - ['hsa-miR-519c-3p' 'hsa-miR-519b-3p' 'hsa-miR-519a-3p']
# ATGGGAG: 1 - ['hsa-miR-7848-3p']
# GCCACGA: 1 - ['hsa-miR-1250-5p']
# ACGACCC: 1 - []
# GACCCTT: 1 - ['hsa-miR-204-3p' 'hsa-miR-4646-5p']
# GAGGGAA: 1 - ['hsa-miR-4287' 'hsa-miR-4685-3p']
# AGGGAAG: 1 - []
# GGAAGGA: 1 - ['hsa-miR-3667-3p']
# AGGCCCT: 1 - ['hsa-miR-4497']
# CCCTTCC: 1 - ['hsa-miR-4747-5p' 'hsa-miR-5196-5p']
# CCTTCCT: 1 - ['hsa-miR-4533']
# GGACATG: 1 - ['hsa-miR-486-5p']
# TGGTGAA: 1 - ['hsa-miR-1255b-2-3p']
# GGAACGT: 1 - ['hsa-miR-6841-3p']
# AACGTGA: 1 - []
# ACGTGAG: 1 - ['hsa-miR-7703']
# GTGAGGA: 1 - ['hsa-miR-483-3p']
# AGGAGAG: 1 - ['hsa-miR-7111-3p']
# TTTTGGC: 1 - ['hsa-miR-548at-3p' 'hsa-miR-548ay-3p']
# GGCACGT: 1 - ['hsa-miR-1973']
# TGTGTGG: 1 - ['hsa-miR-362-3p' 'hsa-miR-329-3p']
# CCCACCT: 1 - ['hsa-miR-363-5p' 'hsa-miR-6745']
# CACCTGT: 1 - ['hsa-miR-3138']
# TGAGTTT: 1 - ['hsa-miR-888-5p']
# GAGTTTA: 1 - ['hsa-miR-372-5p']
# TTTAAAG: 1 - ['hsa-miR-513a-3p' 'hsa-miR-513c-3p' 'hsa-miR-3606-3p']
# TAAATGA: 1 - ['hsa-miR-4699-3p']
# AGAGGGT: 1 - ['hsa-miR-4713-5p']
# GGTCACA: 1 - ['hsa-miR-199a-5p' 'hsa-miR-199b-5p']
# AAATCCT: 1 - []
# AATCCTA: 1 - ['hsa-miR-651-5p']
# AGTGAGG: 1 - []
# TGTCATG: 1 - ['hsa-miR-101-3p']
# ATTGACC: 1 - []
# GACCCCT: 1 - ['hsa-miR-4667-5p' 'hsa-miR-4700-5p' 'hsa-miR-8089']
# ACCCCTG: 1 - ['hsa-miR-6810-5p']
# TCTTGTC: 1 - ['hsa-miR-4773']
# AACCTGA: 1 - ['hsa-miR-4529-3p']
# ACCTGAC: 1 - ['hsa-miR-1269a' 'hsa-miR-1269b']
# AAAAGTT: 1 - []
# AAAGTTC: 1 - []
# GTGTGGA: 1 - ['hsa-miR-1228-3p']
# ATGGGGG: 1 - ['hsa-miR-6798-3p']
# ATTAAAA: 1 - ['hsa-miR-4775']
# CTATAAA: 1 - ['hsa-miR-3145-3p']
# AGAAGTG: 1 - []
# AAGTGAC: 1 - []
# TGACATC: 1 - ['hsa-miR-1183']
# CTTCCAG: 1 - ['hsa-miR-493-3p']
# TTCCAGT: 1 - ['hsa-miR-3974']
# GTTTAGA: 1 - ['hsa-miR-4762-5p']
# TTATATA: 1 - ['hsa-miR-1277-5p']
# ATATACC: 1 - []
# ATACCAT: 1 - []
# ATTTATC: 1 - []
# AACTTTG: 1 - ['hsa-miR-510-3p']
# ATATTTC: 1 - ['hsa-miR-340-5p']
# ATTTCGA: 1 - ['hsa-miR-9-3p']
# ATCTCAG: 1 - []
# GTTTTTT: 1 - ['hsa-miR-3613-3p']
# AATTGTA: 1 - ['hsa-miR-302c-5p']
# ATTGTAT: 1 - []
# CCTATAC: 1 - ['hsa-miR-3201' 'hsa-miR-4791']
# CTATACA: 1 - ['hsa-miR-190a-5p' 'hsa-miR-190b-5p']
# ATACACT: 1 - []
# ACACTAT: 1 - []
# ATCGTTT: 1 - []
# TCGTTTT: 1 - ['hsa-miR-548p']
# TTGAGAT: 1 - ['hsa-miR-618']
# TATCTCT: 1 - ['hsa-miR-3976']
# TCTCTTG: 1 - ['hsa-miR-3925-5p']
# CTCTTGA: 1 - ['hsa-miR-146a-5p' 'hsa-miR-146b-5p' 'hsa-miR-7153-5p']
# AGGTGAG: 1 - []
# GGTGAGA: 1 - ['hsa-miR-6777-3p']
# AGATAAG: 1 - []
# CTACCTA: 1 - ['hsa-miR-3134']
# TACCTAA: 1 - ['hsa-miR-1246']
# CCTAAGA: 1 - ['hsa-miR-4320']
# GATGTCA: 1 - ['hsa-miR-139-5p']
# CACGTCA: 1 - ['hsa-miR-143-5p']
# ATTGTTT: 1 - []
# TTGTGAC: 1 - ['hsa-miR-141-3p' 'hsa-miR-200a-3p']
# TCCCTTT: 1 - ['hsa-miR-5584-5p']
# CTTTGAC: 1 - ['hsa-miR-4738-3p']
# TTTCTTG: 1 - ['hsa-miR-3133']
# TTCTTGA: 1 - ['hsa-miR-4511']
# CCTCGTC: 1 - ['hsa-miR-6081']
# TCGTCCC: 1 - ['hsa-miR-6510-5p']
# GTCCCTG: 1 - ['hsa-miR-211-3p']
# TCATGGT: 1 - ['hsa-miR-624-5p']
# ACCCATG: 1 - ['hsa-miR-1225-5p']
# AAATCTA: 1 - []
# TTAGAGA: 1 - ['hsa-miR-216b-5p']
# AGAGAGT: 1 - []
# TACGTGG: 1 - ['hsa-miR-501-3p' 'hsa-miR-502-3p']
# TTCAACA: 1 - ['hsa-miR-382-5p']
# AACACAG: 1 - ['hsa-miR-599']
# ACAGACC: 1 - ['hsa-miR-1231']
# AGACCCA: 1 - []
# GACCCAC: 1 - ['hsa-miR-6776-5p']
# ACCCACC: 1 - []
# CCCACCC: 1 - ['hsa-miR-6756-5p' 'hsa-miR-6766-5p']
# CCACCCA: 1 - ['hsa-miR-6769a-5p' 'hsa-miR-6769b-5p']
# AGCCCTC: 1 - ['hsa-miR-6771-5p']
# CCTCCTG: 1 - ['hsa-miR-7154-3p']
# CCTCCTT: 1 - ['hsa-miR-766-5p']
# TCCTTCC: 1 - ['hsa-miR-4476' 'hsa-miR-6876-5p']
# TTCCGCG: 1 - ['hsa-miR-525-3p' 'hsa-miR-524-3p']
# CCGCGGG: 1 - ['hsa-miR-6789-3p']
# CTCATGG: 1 - ['hsa-miR-1911-5p']
# TCAGGGT: 1 - ['hsa-miR-5588-3p']
# TCCTGAA: 1 - ['hsa-miR-8083']
# ATGCAGT: 1 - []
# AGTGGTG: 1 - ['hsa-miR-197-3p']
# ACGCTCC: 1 - ['hsa-miR-4737']
# CGCTCCA: 1 - ['hsa-miR-381-5p']
# CCACCAA: 1 - ['hsa-miR-876-3p']
# CACCAAG: 1 - ['hsa-miR-203a-5p']
# ACCAAGA: 1 - []
# AGGAAAC: 1 - []
# AACCTGT: 1 - ['hsa-miR-4520-2-3p']
# AGACCTC: 1 - ['hsa-miR-516b-5p']
# ACCTCCC: 1 - ['hsa-miR-6515-5p']
# CTCCCCG: 1 - ['hsa-miR-423-5p' 'hsa-miR-3184-5p']
# CCCCGGC: 1 - ['hsa-miR-128-1-5p' 'hsa-miR-128-2-5p']
# CGGCGGG: 1 - ['hsa-miR-4632-3p']
# GGGCCTC: 1 - ['hsa-miR-10398-3p']
# CCTCAGG: 1 - ['hsa-miR-1289']
# AGGGAAC: 1 - ['hsa-miR-623']
# AGACCTT: 1 - ['hsa-miR-1299']
# ACCTTTG: 1 - []
# AATATTA: 1 - []
# ATATTAT: 1 - ['hsa-miR-374a-5p' 'hsa-miR-374b-5p']
# TATTTTA: 1 - ['hsa-miR-3163']
# ATATGGA: 1 - ['hsa-miR-3144-3p']
# ATCCAAT: 1 - []
# CAATCCT: 1 - ['hsa-miR-1258']
# ATCCTGT: 1 - []
# ATTTTAA: 1 - []
# ATGGAGT: 1 - ['hsa-miR-4777-3p']
# TGCAGTA: 1 - ['hsa-miR-598-3p']
# ACGTGGT: 1 - []
# CGTGGTA: 1 - ['hsa-miR-767-5p']
# ATCCTCC: 1 - ['hsa-miR-4266']
# ATGAAGA: 1 - ['hsa-miR-3682-5p']
# CGTGGAC: 1 - ['hsa-miR-6804-3p']
# ACGTTTT: 1 - ['hsa-miR-548aw']
# ACGGGAT: 1 - ['hsa-miR-3157-3p']
# CGGGATT: 1 - ['hsa-miR-18b-3p']
# ATATATA: 1 - ['hsa-miR-190a-3p']
# GAGGTCA: 1 - ['hsa-miR-3925-3p']
# AGGTCAC: 1 - []
# GGTCACG: 1 - ['hsa-miR-1825']
# TCACGGG: 1 - ['hsa-miR-371b-3p']
# TTTTGCT: 1 - ['hsa-miR-548ad-3p']
# ATAACAG: 1 - ['hsa-miR-5701']
# TGTGCCC: 1 - ['hsa-miR-602']
# CTCTTGG: 1 - ['hsa-miR-589-5p']
# TGGCCCC: 1 - ['hsa-miR-4655-5p']
# AACATGT: 1 - []
# ACATGTT: 1 - ['hsa-let-7c-3p']
# CTCAACT: 1 - ['hsa-miR-219a-1-3p']
# ACTAGTC: 1 - []
# AGTCATT: 1 - []
# GTCATTT: 1 - ['hsa-miR-545-5p']
# TTTCTCC: 1 - ['hsa-miR-583']
# CCTCTTC: 1 - ['hsa-miR-4434' 'hsa-miR-4516' 'hsa-miR-5703']
# CTCTTCT: 1 - ['hsa-miR-1253']
# TTTTTCA: 1 - ['hsa-miR-12136']
# ACAGAGA: 1 - ['hsa-miR-6818-3p']
# ATCCCTA: 1 - []
# AAGAGGG: 1 - ['hsa-miR-629-3p']
# TCACATC: 1 - ['hsa-miR-4280']
# ATCTGCA: 1 - []
# ATGAAAA: 1 - []
# AAAAAAC: 1 - []
# GTCCTCT: 1 - ['hsa-miR-4768-3p']
# ACTCCTC: 1 - ['hsa-miR-4689' 'hsa-miR-6858-5p']
# TCTTTAC: 1 - ['hsa-miR-5680']
# TTACACT: 1 - ['hsa-miR-8066']
# TACACTG: 1 - ['hsa-miR-4501']
# GCCAGGG: 1 - ['hsa-miR-4746-5p']
# TTTCCAA: 1 - ['hsa-miR-12135']
# AAATTGG: 1 - ['hsa-miR-552-5p']
# GGACAAG: 1 - ['hsa-miR-1266-3p']
# GGGCTCT: 1 - ['hsa-miR-4740-3p']
# AAAGGAG: 1 - []
# AAGGAGA: 1 - ['hsa-miR-3059-5p']
# AGGAGAA: 1 - ['hsa-miR-6881-3p']
# AGAAGAA: 1 - []
# AAGAACA: 1 - ['hsa-miR-578']
# AACATCT: 1 - ['hsa-miR-3674']
# GAACCTC: 1 - ['hsa-miR-432-5p']
# AACCTCC: 1 - []
# ACCTCCT: 1 - []
# CCCTCCC: 1 - ['hsa-miR-149-3p' 'hsa-miR-4728-5p' 'hsa-miR-6785-5p' 'hsa-miR-6883-5p']
# TCCCAGT: 1 - ['hsa-miR-1178-5p']
# AGTCCCT: 1 - ['hsa-miR-12128']
# GTCCCTC: 1 - ['hsa-miR-4270' 'hsa-miR-4441' 'hsa-miR-6754-5p']
# CCCTCGC: 1 - ['hsa-miR-6090']
# ACTCCGC: 1 - ['hsa-miR-6765-5p']
# CAAGAGA: 1 - ['hsa-miR-2117']
# AAGAGAG: 1 - ['hsa-miR-4768-5p' 'hsa-miR-6833-3p']
# ACAGGGT: 1 - ['hsa-miR-4433b-5p']
# GGTCTAT: 1 - ['hsa-miR-488-5p']
# GGTCGTC: 1 - ['hsa-miR-4530']
# GTCGTCT: 1 - ['hsa-miR-922']
# CGTCTCC: 1 - ['hsa-miR-2467-3p']
# CCGAAGA: 1 - ['hsa-miR-6815-3p']
# ACTCTGG: 1 - []
# TAAAGTC: 1 - ['hsa-miR-205-3p']
# GTCACAG: 1 - ['hsa-miR-6733-3p']
# AAGGAAG: 1 - []
# ACCTCAA: 1 - []
# CCTCAAT: 1 - ['hsa-miR-4653-3p']
# CTCAATT: 1 - ['hsa-miR-4424']
# AAACAAG: 1 - []
# AACAAGA: 1 - ['hsa-miR-6739-3p']
# TCTCTCC: 1 - ['hsa-miR-6758-5p' 'hsa-miR-6856-5p']
# CACTTAC: 1 - ['hsa-miR-1257']
# ACTTACC: 1 - []
# ACCTCTC: 1 - []
# CCTCTCT: 1 - ['hsa-miR-185-5p' 'hsa-miR-4306' 'hsa-miR-4644']
# TGTGTTC: 1 - ['hsa-miR-4731-3p' 'hsa-miR-4801']
# TGTTCAG: 1 - ['hsa-miR-6882-5p']
# CAGATGT: 1 - ['hsa-miR-3618']
# GCCTTCC: 1 - ['hsa-miR-6125']
# TTCCATT: 1 - ['hsa-miR-570-5p' 'hsa-miR-548ag' 'hsa-miR-548ai' 'hsa-miR-548ba']
# ATATGTG: 1 - ['hsa-miR-4789-5p']
# TGTGATC: 1 - ['hsa-miR-4704-5p']
# ATCATCT: 1 - []
# CATCTAA: 1 - ['hsa-miR-376a-2-5p']
# CAGTGGG: 1 - ['hsa-miR-6879-3p']
# AGTGGGA: 1 - []
# ATTAGGA: 1 - []
# TTAGGAA: 1 - ['hsa-miR-500a-5p']
# GAGAGGA: 1 - ['hsa-miR-6845-3p']
# AGAGGAG: 1 - ['hsa-miR-4279']
# GTTATAA: 1 - ['hsa-miR-16-2-3p' 'hsa-miR-195-3p']
# TATAATA: 1 - ['hsa-miR-656-3p']
# ATAATAA: 1 - ['hsa-miR-4795-3p']
# TAATAAT: 1 - ['hsa-miR-126-5p']
# AAGATTA: 1 - ['hsa-miR-576-5p']
# GATTAAA: 1 - ['hsa-miR-4735-5p']
# GTAAATA: 1 - ['hsa-miR-4729']
# AATCAGG: 1 - []
# TCCCAAC: 1 - ['hsa-miR-296-3p']
# CCCAACA: 1 - ['hsa-miR-12130']
# ACACATG: 1 - []
# CACATGT: 1 - ['hsa-miR-3177-5p']
# ACATGTC: 1 - ['hsa-let-7a-2-3p' 'hsa-let-7g-3p']
# TTTCACC: 1 - ['hsa-miR-4796-3p']
# TTCACCT: 1 - ['hsa-miR-12117']
# TCACCTC: 1 - ['hsa-miR-12115']
# CACCTCC: 1 - ['hsa-miR-7847-3p']
# ATCTATT: 1 - []
# TTGAGTG: 1 - ['hsa-miR-6750-3p']
# TGAGTGA: 1 - ['hsa-miR-3680-5p']
# AATAGTC: 1 - ['hsa-miR-374a-3p']
# ATAGTCT: 1 - ['hsa-miR-361-5p']
# GTCTCTA: 1 - ['hsa-miR-4756-3p']
# TCTATTT: 1 - ['hsa-miR-577']
# ACTTATC: 1 - ['hsa-miR-5585-3p']
# AGTTTAT: 1 - ['hsa-miR-3671']
# AACTTAA: 1 - []
# CCAACTG: 1 - ['hsa-miR-380-5p' 'hsa-miR-563']
# TTTTTAG: 1 - ['hsa-miR-548c-3p']
# AGACTTT: 1 - []
# GACTTTC: 1 - ['hsa-miR-4766-5p']
# TTTCTTA: 1 - ['hsa-miR-186-5p']
# TTCTTAT: 1 - ['hsa-miR-6507-5p']
# ATCACTT: 1 - ['hsa-miR-3606-5p']
# AGTTAGT: 1 - []
# TACACCT: 1 - ['hsa-miR-4491' 'hsa-miR-4657']
# ACACCTA: 1 - ['hsa-miR-4752']
# CACCTAC: 1 - ['hsa-miR-3691-5p']
# ACCTACT: 1 - []
# CCTACTC: 1 - ['hsa-miR-1255a' 'hsa-miR-1255b-5p']
# ATCAGAG: 1 - ['hsa-miR-4474-5p']
# AGAGAAA: 1 - ['hsa-miR-4753-3p']
# AAGCCAT: 1 - []
# CTAAGGA: 1 - ['hsa-miR-145-3p']
# TGGTGTC: 1 - ['hsa-miR-140-3p']
# CCAGACA: 1 - ['hsa-miR-6753-3p' 'hsa-miR-7107-3p']
# ACACACT: 1 - ['hsa-miR-6818-5p']
# AGATCTT: 1 - []
# TTTCAGG: 1 - ['hsa-miR-6507-3p']
# ATGGGAC: 1 - []
# TGGGACA: 1 - ['hsa-miR-10a-5p' 'hsa-miR-10b-5p']
# ACATTTG: 1 - []
# CATTTGT: 1 - ['hsa-miR-30a-5p' 'hsa-miR-30c-5p' 'hsa-miR-30d-5p' 'hsa-miR-30b-5p'
#  'hsa-miR-30e-5p']
# AGGAAGA: 1 - ['hsa-miR-6868-3p']
# GGAAGAA: 1 - ['hsa-miR-1248']
# GATCAGG: 1 - ['hsa-miR-554']
# TTCAGAA: 1 - ['hsa-miR-1264']
# GACCTGT: 1 - ['hsa-miR-4638-3p']
# GTCGATG: 1 - ['hsa-miR-5690']
# GCCTCTG: 1 - ['hsa-miR-5091']
# CCTCTGC: 1 - ['hsa-miR-139-3p']
# CGAAGAA: 1 - ['hsa-miR-103a-2-5p' 'hsa-miR-103a-1-5p']
# TGTGTGA: 1 - ['hsa-miR-603']
# GTGACAA: 1 - ['hsa-miR-1208']
# ATTTTGA: 1 - []
# TTTTGAA: 1 - ['hsa-miR-5582-3p']
# TTGTGGT: 1 - ['hsa-miR-21-3p' 'hsa-miR-122b-3p']
# ACGACCT: 1 - []
# CAGAGAC: 1 - ['hsa-miR-593-3p']
# AGACATC: 1 - []
# GACATCA: 1 - ['hsa-miR-20b-3p']
# GCATGGC: 1 - ['hsa-miR-126-3p']
# AGTGCAG: 1 - []
# CCGTTTG: 1 - ['hsa-miR-4470']
# GATATGT: 1 - ['hsa-miR-1284']
# ATATGTC: 1 - ['hsa-let-7f-2-3p' 'hsa-miR-1185-2-3p' 'hsa-miR-1185-1-3p']
# ATGGGTA: 1 - ['hsa-miR-5591-3p']
# ATTTAAA: 1 - []
# AGTTTTA: 1 - []
# ACTAACA: 1 - []
# CTAACAG: 1 - ['hsa-miR-219a-5p' 'hsa-miR-4782-3p' 'hsa-miR-6766-3p']
# ACAGGAT: 1 - ['hsa-miR-676-3p']
# AGGATAT: 1 - ['hsa-miR-337-3p']
# TAATGAC: 1 - ['hsa-miR-12132']
# AACCTTC: 1 - []
# CCTTCTG: 1 - ['hsa-miR-7-5p']
# AGGGACA: 1 - []
# ATTATGT: 1 - ['hsa-miR-655-3p' 'hsa-miR-374c-5p']
# ATACAGA: 1 - []
# ACAGAAA: 1 - ['hsa-miR-511-5p']
# GAGAGTG: 1 - ['hsa-miR-12125']
# TCCTTTA: 1 - ['hsa-miR-12124']
# TAGTCTT: 1 - ['hsa-miR-2115-3p']
# TGTTCCA: 1 - ['hsa-miR-624-3p']
# ATCATGA: 1 - []
# TCTCACT: 1 - ['hsa-miR-5586-3p']
# ACTGGAT: 1 - ['hsa-miR-192-5p' 'hsa-miR-215-5p']
# TGAATGG: 1 - ['hsa-miR-9898']
# TGTACCG: 1 - ['hsa-miR-942-3p']
# ACCGGTT: 1 - ['hsa-miR-548s']
# CGGTTCA: 1 - ['hsa-miR-4480']
# GTTCATC: 1 - ['hsa-miR-5697']
# TCATCTG: 1 - ['hsa-miR-411-5p']
# ATCTGGA: 1 - ['hsa-miR-3684']
# ACTTCAA: 1 - []
# AGCAAAC: 1 - []
# ATACCAA: 1 - ['hsa-miR-584-5p']
# TACCAAG: 1 - ['hsa-miR-218-2-3p']
# TGAGCAC: 1 - ['hsa-miR-4636']
# AGCACAG: 1 - []
# GCACAGA: 1 - ['hsa-miR-187-3p']
# ACAGAAG: 1 - []
# CAGAAGA: 1 - ['hsa-miR-6740-3p']
# GTGGAGG: 1 - ['hsa-miR-1306-5p']
# AAAATTC: 1 - []
# AATTCTG: 1 - []
# CTGAGAC: 1 - ['hsa-miR-4522']
# TGAGACT: 1 - ['hsa-miR-4714-5p']
# AGACTGT: 1 - []
# GACTGTA: 1 - ['hsa-miR-6719-3p']
# TGTAGTG: 1 - ['hsa-miR-499a-3p' 'hsa-miR-499b-3p']
# AATCCAT: 1 - ['hsa-miR-6509-5p']
# CACCTAA: 1 - ['hsa-miR-8056']
# ACCTAAA: 1 - []
# ACCTTTT: 1 - []
# ATTTCAT: 1 - []
# TCCCTCC: 1 - ['hsa-miR-1321' 'hsa-miR-4739' 'hsa-miR-4756-5p']
# GAATTTG: 1 - ['hsa-miR-302a-5p']
# GAGTGAC: 1 - ['hsa-miR-1304-3p']
# GACAGTG: 1 - ['hsa-miR-6773-3p']
# ACAGTGG: 1 - []
# TTTTGGG: 1 - ['hsa-miR-548as-3p']
# TTTGGGG: 1 - ['hsa-miR-6771-3p']
# TTTTGGT: 1 - ['hsa-miR-548t-3p' 'hsa-miR-548aa' 'hsa-miR-548ap-3p']
# TTTGGTG: 1 - ['hsa-miR-497-3p']
# TTGGTGG: 1 - ['hsa-miR-6776-3p']
# TATTATA: 1 - ['hsa-miR-5692c' 'hsa-miR-5692b']
# TTATACC: 1 - ['hsa-miR-5583-3p']
# TATACCT: 1 - ['hsa-miR-8076']
# ATACCTT: 1 - []
# ACCAAGG: 1 - ['hsa-miR-218-1-3p']
# GTTTTGA: 1 - ['hsa-miR-1323' 'hsa-miR-548o-3p']
# ACTGGGG: 1 - []
# GTTATTT: 1 - ['hsa-miR-95-5p']
# ATTTTTG: 1 - []
# AAGTGTT: 1 - []
# AGTGTTT: 1 - []
# TTTCATA: 1 - ['hsa-miR-548l']
# TTTACCT: 1 - ['hsa-miR-4694-3p']
# ACCTTCC: 1 - []
# TGGCTGA: 1 - ['hsa-miR-6510-3p']
# ATTCTGC: 1 - ['hsa-miR-208a-3p' 'hsa-miR-208b-3p']
# ACACTGT: 1 - []
# GTACACA: 1 - ['hsa-miR-10226']
# TACACAT: 1 - ['hsa-miR-511-3p']
# CACATAA: 1 - ['hsa-miR-223-5p']
# AAGGATA: 1 - []
# AGGATAC: 1 - ['hsa-miR-202-5p']
# ACTTTAC: 1 - ['hsa-miR-203a-3p']
# AAGTAAG: 1 - []
# TAAGTCT: 1 - ['hsa-miR-892c-5p']
# GTCTCCA: 1 - ['hsa-miR-4257']
# ATAATGG: 1 - ['hsa-miR-556-3p']
# ACTTTGT: 1 - []
# TTGTTTG: 1 - ['hsa-miR-495-3p' 'hsa-miR-5688']
# GTGTTGT: 1 - ['hsa-miR-5003-5p']
# AACTTTC: 1 - []
# TTCCTTG: 1 - ['hsa-miR-12120']
# GTCTGTC: 1 - ['hsa-miR-1324']
# GTCTAGT: 1 - ['hsa-miR-1288-5p']
# ACAGTGT: 1 - []

# %% [markdown]
# # experiments
#
# These temporary cells are not a part of the main code. They're here to test stuff & will be deleted later.

# %%
# code that drops 7mers that doesn't start with an A (experiment for anchor A filtering)
mirna_df["7mer-A1"].replace({"^[C,T,G]": None}, regex=True, inplace=True)

mirna_df.head()
# Out:
#               name               miRNA_seq                cDNA_seq       MRE  \
# 1    hsa-let-7a-5p  UGAGGUAGUAGGUUGUAUAGUU  ACTCCATCATCCAACATATCAA  CTCCATCA
# 2    hsa-let-7a-3p   CUAUACAAUCUACUGUCUUUC   GATATGTTAGATGACAGAAAG  ATATGTTA
# 3  hsa-let-7a-2-3p  CUGUACAGCCUCCUAGCUUUCC  GACATGTCGGAGGATCGAAAGG  ACATGTCG
# 4    hsa-let-7b-5p  UGAGGUAGUAGGUUGUGUGGUU  ACTCCATCATCCAACACACCAA  CTCCATCA
# 5    hsa-let-7b-3p  CUAUACAACCUACUGCCUUCCC  GATATGTTGGATGACGGAAGGG  ATATGTTG
#
#        8mer  7mer-A1  7mer-m8    6mer offset_6mer
# 1  ACTCCATC  ACTCCAT  CTCCATC  CTCCAT      TCCATC
# 2      None     None  ATATGTT  ATATGT      TATGTT
# 3      None     None  ACATGTC  ACATGT      CATGTC
# 4  ACTCCATC  ACTCCAT  CTCCATC  CTCCAT      TCCATC
# 5      None     None  ATATGTT  ATATGT      TATGTT

# %%
# writes whole sequence string to a file

with open("sequence.txt", "w") as export:
    export.write(sequence)

# %%
# find & print specific miRNA from the db


mirna_df.loc[mirna_df['name'] == "hsa-miR-6867-5p"]
# Out:
#                  name                miRNA_seq                 cDNA_seq  \
# 2403  hsa-miR-6867-5p  UGUGUGUGUAGAGGAAGAAGGGA  ACACACACATCTCCTTCTTCCCT
#
#            MRE      8mer  7mer-A1  7mer-m8    6mer offset_6mer
# 2403  CACACACA  ACACACAC  ACACACA  CACACAC  CACACA      ACACAC

# %%
# checks if these two sequences are similar

query1 = "UGUGUGUGUAGAGGAAGAAGGGA"
query2 = "UGUGUGUGUAGAGGAAGAAGGGA"

def check_sequence_similarity(seq1, seq2):
    
    if seq1 == seq2:
        print(seq1 + "\n" + seq2)
        print("Same.")
        
    else:
        print(seq1 + "\n" + seq2)
        print("Different.")
        
check_sequence_similarity(query1, query2)
# Out:
# UGUGUGUGUAGAGGAAGAAGGGA
# UGUGUGUGUAGAGGAAGAAGGGA
# Same.
