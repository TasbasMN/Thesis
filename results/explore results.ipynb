# %%
import pandas as pd

# %%
df = pd.read_csv("results.tsv")

# %%
df[df["flag_column"] == 1]
# Out:
#                    names  start        alignment_string  no_of_base_pairs  \
# 23609      hsa-let-7a-3p    949   010001000100011111110                10
# 25555      hsa-let-7b-3p    948  0000000000100011111110                 8
# 27281    hsa-let-7f-1-3p    948  0000000000100011111110                 8
# 29319      hsa-miR-98-3p    948  0000010000100011111110                 9
# 31423      hsa-let-7c-3p    827  0000000010100011111110                 9
# ...                  ...    ...                     ...               ...
# 4026873      hsa-miR-944   3407  0101000100000011111110                10
# 4028005     hsa-miR-9500   1175     0000011011011111110                11
# 4032358    hsa-miR-95-5p   3544   000001000100111111111                11
# 4037573    hsa-miR-96-3p   4966  0010011010000111111111                13
# 4038188  hsa-miR-1271-5p   1325  1000001100001001111111                11
#
#          no_of_wobbles  no_of_bp+wobbles  flag_column  8mer  7mer-a1  7mer-m8  \
# ...
